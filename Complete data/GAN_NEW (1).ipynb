# %% [markdown]
# # Preprocessing

# %% [markdown]
# Imports

# %%
import numpy             as np
import matplotlib.pyplot as plt
import tensorflow        as tf
import pickle

# %% [markdown]
# Importing Drive and unzipinig the data

# %%
from google.colab import drive
drive.mount('/content/drive')

# !unzip drive/MyDrive/Eye/NewEye
# Out:
# Mounted at /content/drive
# Archive:  drive/MyDrive/Eye/NewEye.zip
#    creating: NewEye/
#    creating: NewEye/test/
#    creating: NewEye/test/AMDD/
#    creating: NewEye/test/AMDD/AMD/
#   inflating: NewEye/test/AMDD/AMD/AMRD46.jpeg
#   inflating: NewEye/test/AMDD/AMD/AMRD47.jpeg
#   inflating: NewEye/test/AMDD/AMD/AMRD48.jpeg
#   inflating: NewEye/test/AMDD/AMD/AMRD49.jpeg
#   inflating: NewEye/test/AMDD/AMD/AMRD50.jpeg
#   inflating: NewEye/test/AMDD/AMD/AMRD51.jpeg
#   inflating: NewEye/test/AMDD/AMD/AMRD52.jpeg
#   inflating: NewEye/test/AMDD/AMD/AMRD53.jpeg
#   inflating: NewEye/test/AMDD/AMD/AMRD54.jpeg
#   inflating: NewEye/test/AMDD/AMD/AMRD55.jpeg
#    creating: NewEye/test/CSRD/
#    creating: NewEye/test/CSRD/CSR/
#   inflating: NewEye/test/CSRD/CSR/CSR100.jpeg
#   inflating: NewEye/test/CSRD/CSR/CSR101.jpeg
#   inflating: NewEye/test/CSRD/CSR/CSR102.jpeg
#   inflating: NewEye/test/CSRD/CSR/CSR93.jpeg
#   inflating: NewEye/test/CSRD/CSR/CSR94.jpeg
#   inflating: NewEye/test/CSRD/CSR/CSR95.jpeg
#   inflating: NewEye/test/CSRD/CSR/CSR96.jpeg
#   inflating: NewEye/test/CSRD/CSR/CSR97.jpeg
#   inflating: NewEye/test/CSRD/CSR/CSR98.jpeg
#   inflating: NewEye/test/CSRD/CSR/CSR99.jpeg
#    creating: NewEye/test/DRD/
#    creating: NewEye/test/DRD/DR/
#   inflating: NewEye/test/DRD/DR/DR100.jpeg
#   inflating: NewEye/test/DRD/DR/DR101.jpeg
#   inflating: NewEye/test/DRD/DR/DR102.jpeg
#   inflating: NewEye/test/DRD/DR/DR103.jpeg
#   inflating: NewEye/test/DRD/DR/DR104.jpeg
#   inflating: NewEye/test/DRD/DR/DR105.jpeg
#   inflating: NewEye/test/DRD/DR/DR106.jpeg
#   inflating: NewEye/test/DRD/DR/DR107.jpeg
#   inflating: NewEye/test/DRD/DR/DR98.jpeg
#   inflating: NewEye/test/DRD/DR/DR99.jpeg
#    creating: NewEye/test/MHD/
#    creating: NewEye/test/MHD/MH/
#   inflating: NewEye/test/MHD/MH/MH100.jpeg
#   inflating: NewEye/test/MHD/MH/MH101.jpeg
#   inflating: NewEye/test/MHD/MH/MH102.jpeg
#   inflating: NewEye/test/MHD/MH/MH93.jpeg
#   inflating: NewEye/test/MHD/MH/MH94.jpeg
#   inflating: NewEye/test/MHD/MH/MH95.jpeg
#   inflating: NewEye/test/MHD/MH/MH96.jpeg
#   inflating: NewEye/test/MHD/MH/MH97.jpeg
#   inflating: NewEye/test/MHD/MH/MH98.jpeg
#   inflating: NewEye/test/MHD/MH/MH99.jpeg
#    creating: NewEye/test/NORMALD/
#    creating: NewEye/test/NORMALD/NORMAL/
#   inflating: NewEye/test/NORMALD/NORMAL/NORMAL197.jpeg
#   inflating: NewEye/test/NORMALD/NORMAL/NORMAL198.jpeg
#   inflating: NewEye/test/NORMALD/NORMAL/NORMAL199.jpeg
#   inflating: NewEye/test/NORMALD/NORMAL/NORMAL200.jpeg
#   inflating: NewEye/test/NORMALD/NORMAL/NORMAL201.jpeg
#   inflating: NewEye/test/NORMALD/NORMAL/NORMAL202.jpeg
#   inflating: NewEye/test/NORMALD/NORMAL/NORMAL203.jpeg
#   inflating: NewEye/test/NORMALD/NORMAL/NORMAL204.jpeg
#   inflating: NewEye/test/NORMALD/NORMAL/NORMAL205.jpeg
#   inflating: NewEye/test/NORMALD/NORMAL/NORMAL206.jpeg
#    creating: NewEye/train/
#    creating: NewEye/train/AMDD/
#    creating: NewEye/train/AMDD/AMD/
#   inflating: NewEye/train/AMDD/AMD/AMRD1.jpeg
#   inflating: NewEye/train/AMDD/AMD/AMRD10.jpeg
#   inflating: NewEye/train/AMDD/AMD/AMRD11.jpeg
#   inflating: NewEye/train/AMDD/AMD/AMRD12.jpeg
#   inflating: NewEye/train/AMDD/AMD/AMRD13.jpeg
#   inflating: NewEye/train/AMDD/AMD/AMRD14.jpeg
#   inflating: NewEye/train/AMDD/AMD/AMRD15.jpeg
#   inflating: NewEye/train/AMDD/AMD/AMRD16.jpeg
#   inflating: NewEye/train/AMDD/AMD/AMRD17.jpeg
#   inflating: NewEye/train/AMDD/AMD/AMRD18.jpeg
#   inflating: NewEye/train/AMDD/AMD/AMRD19.jpeg
#   inflating: NewEye/train/AMDD/AMD/AMRD2.jpeg
#   inflating: NewEye/train/AMDD/AMD/AMRD20.jpeg
#   inflating: NewEye/train/AMDD/AMD/AMRD21.jpeg
#   inflating: NewEye/train/AMDD/AMD/AMRD22.jpeg
#   inflating: NewEye/train/AMDD/AMD/AMRD23.jpeg
#   inflating: NewEye/train/AMDD/AMD/AMRD24.jpeg
#   inflating: NewEye/train/AMDD/AMD/AMRD25.jpeg
#   inflating: NewEye/train/AMDD/AMD/AMRD26.jpeg
#   inflating: NewEye/train/AMDD/AMD/AMRD27.jpeg
#   inflating: NewEye/train/AMDD/AMD/AMRD28.jpeg
#   inflating: NewEye/train/AMDD/AMD/AMRD29.jpeg
#   inflating: NewEye/train/AMDD/AMD/AMRD3.jpeg
#   inflating: NewEye/train/AMDD/AMD/AMRD30.jpeg
#   inflating: NewEye/train/AMDD/AMD/AMRD31.jpeg
#   inflating: NewEye/train/AMDD/AMD/AMRD32.jpeg
#   inflating: NewEye/train/AMDD/AMD/AMRD33.jpeg
#   inflating: NewEye/train/AMDD/AMD/AMRD34.jpeg
#   inflating: NewEye/train/AMDD/AMD/AMRD35.jpeg
#   inflating: NewEye/train/AMDD/AMD/AMRD36.jpeg
#   inflating: NewEye/train/AMDD/AMD/AMRD37.jpeg
#   inflating: NewEye/train/AMDD/AMD/AMRD38.jpeg
#   inflating: NewEye/train/AMDD/AMD/AMRD39.jpeg
#   inflating: NewEye/train/AMDD/AMD/AMRD4.jpeg
#   inflating: NewEye/train/AMDD/AMD/AMRD40.jpeg
#   inflating: NewEye/train/AMDD/AMD/AMRD41.jpeg
#   inflating: NewEye/train/AMDD/AMD/AMRD42.jpeg
#   inflating: NewEye/train/AMDD/AMD/AMRD43.jpeg
#   inflating: NewEye/train/AMDD/AMD/AMRD44.jpeg
#   inflating: NewEye/train/AMDD/AMD/AMRD45.jpeg
#   inflating: NewEye/train/AMDD/AMD/AMRD5.jpeg
#   inflating: NewEye/train/AMDD/AMD/AMRD6.jpeg
#   inflating: NewEye/train/AMDD/AMD/AMRD7.jpeg
#   inflating: NewEye/train/AMDD/AMD/AMRD8.jpeg
#   inflating: NewEye/train/AMDD/AMD/AMRD9.jpeg
#    creating: NewEye/train/CSRD/
#    creating: NewEye/train/CSRD/CSR/
#   inflating: NewEye/train/CSRD/CSR/CSR1.jpeg
#   inflating: NewEye/train/CSRD/CSR/CSR10.jpeg
#   inflating: NewEye/train/CSRD/CSR/CSR11.jpeg
#   inflating: NewEye/train/CSRD/CSR/CSR12.jpeg
#   inflating: NewEye/train/CSRD/CSR/CSR13.jpeg
#   inflating: NewEye/train/CSRD/CSR/CSR14.jpeg
#   inflating: NewEye/train/CSRD/CSR/CSR15.jpeg
#   inflating: NewEye/train/CSRD/CSR/CSR16.jpeg
#   inflating: NewEye/train/CSRD/CSR/CSR17.jpeg
#   inflating: NewEye/train/CSRD/CSR/CSR18.jpeg
#   inflating: NewEye/train/CSRD/CSR/CSR19.jpeg
#   inflating: NewEye/train/CSRD/CSR/CSR2.jpeg
#   inflating: NewEye/train/CSRD/CSR/CSR20.jpeg
#   inflating: NewEye/train/CSRD/CSR/CSR21.jpeg
#   inflating: NewEye/train/CSRD/CSR/CSR22.jpeg
#   inflating: NewEye/train/CSRD/CSR/CSR23.jpeg
#   inflating: NewEye/train/CSRD/CSR/CSR24.jpeg
#   inflating: NewEye/train/CSRD/CSR/CSR25.jpeg
#   inflating: NewEye/train/CSRD/CSR/CSR26.jpeg
#   inflating: NewEye/train/CSRD/CSR/CSR27.jpeg
#   inflating: NewEye/train/CSRD/CSR/CSR28.jpeg
#   inflating: NewEye/train/CSRD/CSR/CSR29.jpeg
#   inflating: NewEye/train/CSRD/CSR/CSR3.jpeg
#   inflating: NewEye/train/CSRD/CSR/CSR30.jpeg
#   inflating: NewEye/train/CSRD/CSR/CSR31.jpeg
#   inflating: NewEye/train/CSRD/CSR/CSR32.jpeg
#   inflating: NewEye/train/CSRD/CSR/CSR33.jpeg
#   inflating: NewEye/train/CSRD/CSR/CSR34.jpeg
#   inflating: NewEye/train/CSRD/CSR/CSR35.jpeg
#   inflating: NewEye/train/CSRD/CSR/CSR36.jpeg
#   inflating: NewEye/train/CSRD/CSR/CSR37.jpeg
#   inflating: NewEye/train/CSRD/CSR/CSR38.jpeg
#   inflating: NewEye/train/CSRD/CSR/CSR39.jpeg
#   inflating: NewEye/train/CSRD/CSR/CSR4.jpeg
#   inflating: NewEye/train/CSRD/CSR/CSR40.jpeg
#   inflating: NewEye/train/CSRD/CSR/CSR41.jpeg
#   inflating: NewEye/train/CSRD/CSR/CSR42.jpeg
#   inflating: NewEye/train/CSRD/CSR/CSR43.jpeg
#   inflating: NewEye/train/CSRD/CSR/CSR44.jpeg
#   inflating: NewEye/train/CSRD/CSR/CSR45.jpeg
#   inflating: NewEye/train/CSRD/CSR/CSR46.jpeg
#   inflating: NewEye/train/CSRD/CSR/CSR47.jpeg
#   inflating: NewEye/train/CSRD/CSR/CSR48.jpeg
#   inflating: NewEye/train/CSRD/CSR/CSR49.jpeg
#   inflating: NewEye/train/CSRD/CSR/CSR5.jpeg
#   inflating: NewEye/train/CSRD/CSR/CSR50.jpeg
#   inflating: NewEye/train/CSRD/CSR/CSR51.jpeg
#   inflating: NewEye/train/CSRD/CSR/CSR52.jpeg
#   inflating: NewEye/train/CSRD/CSR/CSR53.jpeg
#   inflating: NewEye/train/CSRD/CSR/CSR54.jpeg
#   inflating: NewEye/train/CSRD/CSR/CSR55.jpeg
#   inflating: NewEye/train/CSRD/CSR/CSR56.jpeg
#   inflating: NewEye/train/CSRD/CSR/CSR57.jpeg
#   inflating: NewEye/train/CSRD/CSR/CSR58.jpeg
#   inflating: NewEye/train/CSRD/CSR/CSR59.jpeg
#   inflating: NewEye/train/CSRD/CSR/CSR6.jpeg
#   inflating: NewEye/train/CSRD/CSR/CSR60.jpeg
#   inflating: NewEye/train/CSRD/CSR/CSR61.jpeg
#   inflating: NewEye/train/CSRD/CSR/CSR62.jpeg
#   inflating: NewEye/train/CSRD/CSR/CSR63.jpeg
#   inflating: NewEye/train/CSRD/CSR/CSR64.jpeg
#   inflating: NewEye/train/CSRD/CSR/CSR65.jpeg
#   inflating: NewEye/train/CSRD/CSR/CSR66.jpeg
#   inflating: NewEye/train/CSRD/CSR/CSR67.jpeg
#   inflating: NewEye/train/CSRD/CSR/CSR68.jpeg
#   inflating: NewEye/train/CSRD/CSR/CSR69.jpeg
#   inflating: NewEye/train/CSRD/CSR/CSR7.jpeg
#   inflating: NewEye/train/CSRD/CSR/CSR70.jpeg
#   inflating: NewEye/train/CSRD/CSR/CSR71.jpeg
#   inflating: NewEye/train/CSRD/CSR/CSR72.jpeg
#   inflating: NewEye/train/CSRD/CSR/CSR73.jpeg
#   inflating: NewEye/train/CSRD/CSR/CSR74.jpeg
#   inflating: NewEye/train/CSRD/CSR/CSR75.jpeg
#   inflating: NewEye/train/CSRD/CSR/CSR76.jpeg
#   inflating: NewEye/train/CSRD/CSR/CSR77.jpeg
#   inflating: NewEye/train/CSRD/CSR/CSR78.jpeg
#   inflating: NewEye/train/CSRD/CSR/CSR79.jpeg
#   inflating: NewEye/train/CSRD/CSR/CSR8.jpeg
#   inflating: NewEye/train/CSRD/CSR/CSR80.jpeg
#   inflating: NewEye/train/CSRD/CSR/CSR81.jpeg
#   inflating: NewEye/train/CSRD/CSR/CSR82.jpeg
#   inflating: NewEye/train/CSRD/CSR/CSR83.jpeg
#   inflating: NewEye/train/CSRD/CSR/CSR84.jpeg
#   inflating: NewEye/train/CSRD/CSR/CSR85.jpeg
#   inflating: NewEye/train/CSRD/CSR/CSR86.jpeg
#   inflating: NewEye/train/CSRD/CSR/CSR87.jpeg
#   inflating: NewEye/train/CSRD/CSR/CSR88.jpeg
#   inflating: NewEye/train/CSRD/CSR/CSR89.jpeg
#   inflating: NewEye/train/CSRD/CSR/CSR9.jpeg
#   inflating: NewEye/train/CSRD/CSR/CSR90.jpeg
#   inflating: NewEye/train/CSRD/CSR/CSR91.jpeg
#   inflating: NewEye/train/CSRD/CSR/CSR92.jpeg
#    creating: NewEye/train/DRD/
#    creating: NewEye/train/DRD/DR/
#   inflating: NewEye/train/DRD/DR/DR1.jpeg
#   inflating: NewEye/train/DRD/DR/DR10.jpeg
#   inflating: NewEye/train/DRD/DR/DR11.jpeg
#   inflating: NewEye/train/DRD/DR/DR12.jpeg
#   inflating: NewEye/train/DRD/DR/DR13.jpeg
#   inflating: NewEye/train/DRD/DR/DR14.jpeg
#   inflating: NewEye/train/DRD/DR/DR15.jpeg
#   inflating: NewEye/train/DRD/DR/DR16.jpeg
#   inflating: NewEye/train/DRD/DR/DR17.jpeg
#   inflating: NewEye/train/DRD/DR/DR18.jpeg
#   inflating: NewEye/train/DRD/DR/DR19.jpeg
#   inflating: NewEye/train/DRD/DR/DR2.jpeg
#   inflating: NewEye/train/DRD/DR/DR20.jpeg
#   inflating: NewEye/train/DRD/DR/DR21.jpeg
#   inflating: NewEye/train/DRD/DR/DR22.jpeg
#   inflating: NewEye/train/DRD/DR/DR23.jpeg
#   inflating: NewEye/train/DRD/DR/DR24.jpeg
#   inflating: NewEye/train/DRD/DR/DR25.jpeg
#   inflating: NewEye/train/DRD/DR/DR26.jpeg
#   inflating: NewEye/train/DRD/DR/DR27.jpeg
#   inflating: NewEye/train/DRD/DR/DR28.jpeg
#   inflating: NewEye/train/DRD/DR/DR29.jpeg
#   inflating: NewEye/train/DRD/DR/DR3.jpeg
#   inflating: NewEye/train/DRD/DR/DR30.jpeg
#   inflating: NewEye/train/DRD/DR/DR31.jpeg
#   inflating: NewEye/train/DRD/DR/DR32.jpeg
#   inflating: NewEye/train/DRD/DR/DR33.jpeg
#   inflating: NewEye/train/DRD/DR/DR34.jpeg
#   inflating: NewEye/train/DRD/DR/DR35.jpeg
#   inflating: NewEye/train/DRD/DR/DR36.jpeg
#   inflating: NewEye/train/DRD/DR/DR37.jpeg
#   inflating: NewEye/train/DRD/DR/DR38.jpeg
#   inflating: NewEye/train/DRD/DR/DR39.jpeg
#   inflating: NewEye/train/DRD/DR/DR4.jpeg
#   inflating: NewEye/train/DRD/DR/DR40.jpeg
#   inflating: NewEye/train/DRD/DR/DR41.jpeg
#   inflating: NewEye/train/DRD/DR/DR42.jpeg
#   inflating: NewEye/train/DRD/DR/DR43.jpeg
#   inflating: NewEye/train/DRD/DR/DR44.jpeg
#   inflating: NewEye/train/DRD/DR/DR45.jpeg
#   inflating: NewEye/train/DRD/DR/DR46.jpeg
#   inflating: NewEye/train/DRD/DR/DR47.jpeg
#   inflating: NewEye/train/DRD/DR/DR48.jpeg
#   inflating: NewEye/train/DRD/DR/DR49.jpeg
#   inflating: NewEye/train/DRD/DR/DR5.jpeg
#   inflating: NewEye/train/DRD/DR/DR50.jpeg
#   inflating: NewEye/train/DRD/DR/DR51.jpeg
#   inflating: NewEye/train/DRD/DR/DR52.jpeg
#   inflating: NewEye/train/DRD/DR/DR53.jpeg
#   inflating: NewEye/train/DRD/DR/DR54.jpeg
#   inflating: NewEye/train/DRD/DR/DR55.jpeg
#   inflating: NewEye/train/DRD/DR/DR56.jpeg
#   inflating: NewEye/train/DRD/DR/DR57.jpeg
#   inflating: NewEye/train/DRD/DR/DR58.jpeg
#   inflating: NewEye/train/DRD/DR/DR59.jpeg
#   inflating: NewEye/train/DRD/DR/DR6.jpeg
#   inflating: NewEye/train/DRD/DR/DR60.jpeg
#   inflating: NewEye/train/DRD/DR/DR61.jpeg
#   inflating: NewEye/train/DRD/DR/DR62.jpeg
#   inflating: NewEye/train/DRD/DR/DR63.jpeg
#   inflating: NewEye/train/DRD/DR/DR64.jpeg
#   inflating: NewEye/train/DRD/DR/DR65.jpeg
#   inflating: NewEye/train/DRD/DR/DR66.jpeg
#   inflating: NewEye/train/DRD/DR/DR67.jpeg
#   inflating: NewEye/train/DRD/DR/DR68.jpeg
#   inflating: NewEye/train/DRD/DR/DR69.jpeg
#   inflating: NewEye/train/DRD/DR/DR7.jpeg
#   inflating: NewEye/train/DRD/DR/DR70.jpeg
#   inflating: NewEye/train/DRD/DR/DR71.jpeg
#   inflating: NewEye/train/DRD/DR/DR72.jpeg
#   inflating: NewEye/train/DRD/DR/DR73.jpeg
#   inflating: NewEye/train/DRD/DR/DR74.jpeg
#   inflating: NewEye/train/DRD/DR/DR75.jpeg
#   inflating: NewEye/train/DRD/DR/DR76.jpeg
#   inflating: NewEye/train/DRD/DR/DR77.jpeg
#   inflating: NewEye/train/DRD/DR/DR78.jpeg
#   inflating: NewEye/train/DRD/DR/DR79.jpeg
#   inflating: NewEye/train/DRD/DR/DR8.jpeg
#   inflating: NewEye/train/DRD/DR/DR80.jpeg
#   inflating: NewEye/train/DRD/DR/DR81.jpeg
#   inflating: NewEye/train/DRD/DR/DR82.jpeg
#   inflating: NewEye/train/DRD/DR/DR83.jpeg
#   inflating: NewEye/train/DRD/DR/DR84.jpeg
#   inflating: NewEye/train/DRD/DR/DR85.jpeg
#   inflating: NewEye/train/DRD/DR/DR86.jpeg
#   inflating: NewEye/train/DRD/DR/DR87.jpeg
#   inflating: NewEye/train/DRD/DR/DR88.jpeg
#   inflating: NewEye/train/DRD/DR/DR89.jpeg
#   inflating: NewEye/train/DRD/DR/DR9.jpeg
#   inflating: NewEye/train/DRD/DR/DR90.jpeg
#   inflating: NewEye/train/DRD/DR/DR91.jpeg
#   inflating: NewEye/train/DRD/DR/DR92.jpeg
#   inflating: NewEye/train/DRD/DR/DR93.jpeg
#   inflating: NewEye/train/DRD/DR/DR94.jpeg
#   inflating: NewEye/train/DRD/DR/DR95.jpeg
#   inflating: NewEye/train/DRD/DR/DR96.jpeg
#   inflating: NewEye/train/DRD/DR/DR97.jpeg
#    creating: NewEye/train/MHD/
#    creating: NewEye/train/MHD/MH/
#   inflating: NewEye/train/MHD/MH/MH1.jpeg
#   inflating: NewEye/train/MHD/MH/MH10.jpeg
#   inflating: NewEye/train/MHD/MH/MH11.jpeg
#   inflating: NewEye/train/MHD/MH/MH12.jpeg
#   inflating: NewEye/train/MHD/MH/MH13.jpeg
#   inflating: NewEye/train/MHD/MH/MH14.jpeg
#   inflating: NewEye/train/MHD/MH/MH15.jpeg
#   inflating: NewEye/train/MHD/MH/MH16.jpeg
#   inflating: NewEye/train/MHD/MH/MH17.jpeg
#   inflating: NewEye/train/MHD/MH/MH18.jpeg
#   inflating: NewEye/train/MHD/MH/MH19.jpeg
#   inflating: NewEye/train/MHD/MH/MH2.jpeg
#   inflating: NewEye/train/MHD/MH/MH20.jpeg
#   inflating: NewEye/train/MHD/MH/MH21.jpeg
#   inflating: NewEye/train/MHD/MH/MH22.jpeg
#   inflating: NewEye/train/MHD/MH/MH23.jpeg
#   inflating: NewEye/train/MHD/MH/MH24.jpeg
#   inflating: NewEye/train/MHD/MH/MH25.jpeg
#   inflating: NewEye/train/MHD/MH/MH26.jpeg
#   inflating: NewEye/train/MHD/MH/MH27.jpeg
#   inflating: NewEye/train/MHD/MH/MH28.jpeg
#   inflating: NewEye/train/MHD/MH/MH29.jpeg
#   inflating: NewEye/train/MHD/MH/MH3.jpeg
#   inflating: NewEye/train/MHD/MH/MH30.jpeg
#   inflating: NewEye/train/MHD/MH/MH31.jpeg
#   inflating: NewEye/train/MHD/MH/MH32.jpeg
#   inflating: NewEye/train/MHD/MH/MH33.jpeg
#   inflating: NewEye/train/MHD/MH/MH34.jpeg
#   inflating: NewEye/train/MHD/MH/MH35.jpeg
#   inflating: NewEye/train/MHD/MH/MH36.jpeg
#   inflating: NewEye/train/MHD/MH/MH37.jpeg
#   inflating: NewEye/train/MHD/MH/MH38.jpeg
#   inflating: NewEye/train/MHD/MH/MH39.jpeg
#   inflating: NewEye/train/MHD/MH/MH4.jpeg
#   inflating: NewEye/train/MHD/MH/MH40.jpeg
#   inflating: NewEye/train/MHD/MH/MH41.jpeg
#   inflating: NewEye/train/MHD/MH/MH42.jpeg
#   inflating: NewEye/train/MHD/MH/MH43.jpeg
#   inflating: NewEye/train/MHD/MH/MH44.jpeg
#   inflating: NewEye/train/MHD/MH/MH45.jpeg
#   inflating: NewEye/train/MHD/MH/MH46.jpeg
#   inflating: NewEye/train/MHD/MH/MH47.jpeg
#   inflating: NewEye/train/MHD/MH/MH48.jpeg
#   inflating: NewEye/train/MHD/MH/MH49.jpeg
#   inflating: NewEye/train/MHD/MH/MH5.jpeg
#   inflating: NewEye/train/MHD/MH/MH50.jpeg
#   inflating: NewEye/train/MHD/MH/MH51.jpeg
#   inflating: NewEye/train/MHD/MH/MH52.jpeg
#   inflating: NewEye/train/MHD/MH/MH53.jpeg
#   inflating: NewEye/train/MHD/MH/MH54.jpeg
#   inflating: NewEye/train/MHD/MH/MH55.jpeg
#   inflating: NewEye/train/MHD/MH/MH56.jpeg
#   inflating: NewEye/train/MHD/MH/MH57.jpeg
#   inflating: NewEye/train/MHD/MH/MH58.jpeg
#   inflating: NewEye/train/MHD/MH/MH59.jpeg
#   inflating: NewEye/train/MHD/MH/MH6.jpeg
#   inflating: NewEye/train/MHD/MH/MH60.jpeg
#   inflating: NewEye/train/MHD/MH/MH61.jpeg
#   inflating: NewEye/train/MHD/MH/MH62.jpeg
#   inflating: NewEye/train/MHD/MH/MH63.jpeg
#   inflating: NewEye/train/MHD/MH/MH64.jpeg
#   inflating: NewEye/train/MHD/MH/MH65.jpeg
#   inflating: NewEye/train/MHD/MH/MH66.jpeg
#   inflating: NewEye/train/MHD/MH/MH67.jpeg
#   inflating: NewEye/train/MHD/MH/MH68.jpeg
#   inflating: NewEye/train/MHD/MH/MH69.jpeg
#   inflating: NewEye/train/MHD/MH/MH7.jpeg
#   inflating: NewEye/train/MHD/MH/MH70.jpeg
#   inflating: NewEye/train/MHD/MH/MH71.jpeg
#   inflating: NewEye/train/MHD/MH/MH72.jpeg
#   inflating: NewEye/train/MHD/MH/MH73.jpeg
#   inflating: NewEye/train/MHD/MH/MH74.jpeg
#   inflating: NewEye/train/MHD/MH/MH75.jpeg
#   inflating: NewEye/train/MHD/MH/MH76.jpeg
#   inflating: NewEye/train/MHD/MH/MH77.jpeg
#   inflating: NewEye/train/MHD/MH/MH78.jpeg
#   inflating: NewEye/train/MHD/MH/MH79.jpeg
#   inflating: NewEye/train/MHD/MH/MH8.jpeg
#   inflating: NewEye/train/MHD/MH/MH80.jpeg
#   inflating: NewEye/train/MHD/MH/MH81.jpeg
#   inflating: NewEye/train/MHD/MH/MH82.jpeg
#   inflating: NewEye/train/MHD/MH/MH83.jpeg
#   inflating: NewEye/train/MHD/MH/MH84.jpeg
#   inflating: NewEye/train/MHD/MH/MH85.jpeg
#   inflating: NewEye/train/MHD/MH/MH86.jpeg
#   inflating: NewEye/train/MHD/MH/MH87.jpeg
#   inflating: NewEye/train/MHD/MH/MH88.jpeg
#   inflating: NewEye/train/MHD/MH/MH89.jpeg
#   inflating: NewEye/train/MHD/MH/MH9.jpeg
#   inflating: NewEye/train/MHD/MH/MH90.jpeg
#   inflating: NewEye/train/MHD/MH/MH91.jpeg
#   inflating: NewEye/train/MHD/MH/MH92.jpeg
#    creating: NewEye/train/NORMALD/
#    creating: NewEye/train/NORMALD/NORMAL/
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL1.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL10.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL100.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL101.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL102.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL103.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL104.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL105.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL106.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL107.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL108.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL109.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL11.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL110.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL111.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL112.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL113.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL114.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL115.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL116.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL117.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL118.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL119.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL12.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL120.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL121.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL122.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL123.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL124.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL125.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL126.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL127.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL128.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL129.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL13.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL130.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL131.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL132.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL133.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL134.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL135.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL136.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL137.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL138.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL139.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL14.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL140.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL141.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL142.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL143.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL144.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL145.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL146.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL147.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL148.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL149.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL15.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL150.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL151.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL152.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL153.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL154.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL155.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL156.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL157.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL158.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL159.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL16.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL160.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL161.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL162.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL163.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL164.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL165.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL166.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL167.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL168.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL169.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL17.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL170.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL171.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL172.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL173.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL174.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL175.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL176.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL177.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL178.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL179.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL18.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL180.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL181.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL182.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL183.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL184.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL185.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL186.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL187.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL188.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL189.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL19.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL190.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL191.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL192.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL193.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL194.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL195.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL196.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL2.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL20.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL21.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL22.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL23.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL24.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL25.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL26.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL27.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL28.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL29.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL3.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL30.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL31.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL32.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL33.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL34.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL35.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL36.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL37.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL38.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL39.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL4.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL40.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL41.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL42.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL43.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL44.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL45.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL46.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL47.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL48.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL49.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL5.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL50.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL51.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL52.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL53.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL54.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL55.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL56.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL57.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL58.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL59.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL6.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL60.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL61.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL62.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL63.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL64.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL65.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL66.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL67.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL68.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL69.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL7.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL70.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL71.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL72.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL73.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL74.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL75.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL76.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL77.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL78.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL79.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL8.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL80.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL81.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL82.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL83.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL84.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL85.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL86.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL87.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL88.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL89.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL9.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL90.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL91.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL92.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL93.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL94.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL95.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL96.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL97.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL98.jpeg
#   inflating: NewEye/train/NORMALD/NORMAL/NORMAL99.jpeg

# %%
file_name='history.pkl'

# %% [markdown]
# Determining the batch size

# %%
batch_size = 2

# %% [markdown]
# Defining the data generators

# %%
# AMD_datagen = tf.keras.preprocessing.image.ImageDataGenerator(
#     rescale            = 1./255,
#     rotation_range     = 8,
#     width_shift_range  = 0.1,
#     height_shift_range = 0.1
# )

# CSR_datagen = tf.keras.preprocessing.image.ImageDataGenerator(
#     rescale            = 1./255,
#     rotation_range     = 8,
#     width_shift_range  = 0.1,
#     height_shift_range = 0.1
# )

DR_datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale            = 1./255,
    rotation_range     = 8,
    width_shift_range  = 0.1,
    height_shift_range = 0.1
)

MH_datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale            = 1./255,
    rotation_range     = 8,
    width_shift_range  = 0.1,
    height_shift_range = 0.1
)

NORMAL_datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale            = 1./255,
    rotation_range     = 8,
    width_shift_range  = 0.1,
    height_shift_range = 0.1
)

# %%
# AMD_data = AMD_datagen.flow_from_directory(
#     'NewEye/train/AMDD',
#     # target_size = (832,576),
#     target_size = (416,288),
#     batch_size  = batch_size,
#     color_mode  = "grayscale",
#     class_mode  = None,
#     shuffle     = True
# )

# %%
# CSR_data = CSR_datagen.flow_from_directory(
#     'NewEye/train/CSRD',
#     target_size = (416,288),
#     batch_size  = batch_size,
#     color_mode  = "grayscale",
#     class_mode  = None,
#     shuffle     = True
# )

# %%
DR_data = DR_datagen.flow_from_directory(
    'NewEye/train/D/DRD',
    target_size = (416,288),
    batch_size  = batch_size,
    color_mode  = "grayscale",
    class_mode  = None,
    shuffle     = True
)
# Out:
# Found 97 images belonging to 1 classes.

# %%
MH_data = MH_datagen.flow_from_directory(
    'NewEye/train/D/MHD',
    target_size = (416,288),
    batch_size  = batch_size,
    color_mode  = "grayscale",
    class_mode  = None,
    shuffle     = True
)
# Out:
# Found 92 images belonging to 1 classes.

# %%
NORMAL_data = NORMAL_datagen.flow_from_directory(
    'NewEye/train/D/NORMALD',
    target_size = (416,288),
    batch_size  = batch_size,
    color_mode  = "grayscale",
    class_mode  = None,
    shuffle     = True
)
# Out:
# Found 196 images belonging to 1 classes.

# %%
test_datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale            = 1./255
)

test_data = test_datagen.flow_from_directory(
    'NewEye/test/D',
    target_size = (416,288),
    batch_size  = batch_size,
    color_mode  = "grayscale",
    class_mode  = "categorical",
)
# Out:
# Found 30 images belonging to 3 classes.

# %% [markdown]
# #Building the Model

# %% [markdown]
# Defining the Custom Activation Function

# %%
# custom activation function
def custom_activation(output):
  logexpsum = tf.keras.backend.sum(tf.keras.backend.exp(output), axis=-1, keepdims=True)
  result    = logexpsum / (logexpsum + 1.0)

  return result

# %% [markdown]
# Defining Discriminator and the Classification model

# %%
def define_discriminator(in_shape=(416,288,1), n_classes = 3):
  in_image = tf.keras.layers.Input(shape=in_shape)

  fe = tf.keras.layers.Conv2D(128, (3,3), strides = (1,1), padding = "same")(in_image)
  fe = tf.keras.layers.MaxPool2D(pool_size = (2,2) , strides = (2,2))(fe)
  fe = tf.keras.layers.LeakyReLU(alpha=0.2)(fe)

 # fe = tf.keras.layers.Dropout(0.1)(fe)

  fe = tf.keras.layers.Conv2D(128, (3,3), strides = (1,1), padding = "same")(fe)
  fe = tf.keras.layers.MaxPool2D(pool_size = (2,2) , strides = (2,2))(fe)
  fe = tf.keras.layers.LeakyReLU(alpha=0.2)(fe)

  #fe = tf.keras.layers.Dropout(0.1)(fe)

  fe = tf.keras.layers.Conv2D(128, (3,3), strides = (1,1), padding = "same")(fe)
  fe = tf.keras.layers.MaxPool2D(pool_size = (2,2) , strides = (2,2))(fe)
  fe = tf.keras.layers.LeakyReLU(alpha=0.2)(fe)

  #fe = tf.keras.layers.Dropout(0.1)(fe)

  fe = tf.keras.layers.Conv2D(128, (3,3), strides = (1,1), padding = "same")(fe)
  fe = tf.keras.layers.MaxPool2D(pool_size = (2,2) , strides = (2,2))(fe)
  fe = tf.keras.layers.LeakyReLU(alpha=0.2)(fe)

  #fe = tf.keras.layers.Dropout(0.1)(fe)

  fe = tf.keras.layers.Conv2D(128, (3,3), strides = (1,1), padding = "same")(fe)
  fe = tf.keras.layers.MaxPool2D(pool_size = (2,2) , strides = (2,2))(fe)
  fe = tf.keras.layers.LeakyReLU(alpha=0.2)(fe)

  # fe = tf.keras.layers.Conv2D(128, (3,3), strides = (1,1), padding = "same")(fe)
  # fe = tf.keras.layers.MaxPool2D(pool_size = (2,2) , strides = (2,2))(fe)
  # fe = tf.keras.layers.LeakyReLU(alpha=0.2)(fe)

  fe = tf.keras.layers.Flatten()(fe)
  fe = tf.keras.layers.Dropout(0.4)(fe)
  fe = tf.keras.layers.Dense(n_classes)(fe)

  c_out_layer = tf.keras.layers.Activation("softmax")(fe)
  c_model     = tf.keras.models.Model(in_image, c_out_layer)
  c_model.compile(loss = "categorical_crossentropy", optimizer = tf.keras.optimizers.Adam(learning_rate = 0.00002,  beta_1 = 0.5), metrics = ["accuracy"])

  d_out_layer = tf.keras.layers.Lambda(custom_activation)(fe)
  d_model     = tf.keras.models.Model(in_image, d_out_layer)
  d_model.compile(loss = "binary_crossentropy", optimizer = tf.keras.optimizers.Adam(learning_rate = 0.00002, beta_1 = 0.5))
  return d_model, c_model

# %% [markdown]
# Defining the Generator

# %%
def define_generator(latent_dim):
  in_lat  = tf.keras.layers.Input(shape=(latent_dim,))
  n_nodes = 128 * 13 * 9

  gen = tf.keras.layers.Dense(n_nodes)(in_lat)
  gen = tf.keras.layers.LeakyReLU(alpha = 0.2)(gen)
  gen = tf.keras.layers.Reshape((13, 9, 128))(gen)

  gen = tf.keras.layers.Conv2DTranspose(128, (4,4), strides = (2,2), padding = "same")(gen)
  gen = tf.keras.layers.LeakyReLU(alpha = 0.2)(gen)

  gen = tf.keras.layers.Conv2DTranspose(128, (4,4), strides = (2,2), padding = "same")(gen)
  gen = tf.keras.layers.LeakyReLU(alpha = 0.2)(gen)

  gen = tf.keras.layers.Conv2DTranspose(128, (4,4), strides = (2,2), padding = "same")(gen)
  gen = tf.keras.layers.LeakyReLU(alpha = 0.2)(gen)

  gen = tf.keras.layers.Conv2DTranspose(128, (4,4), strides = (2,2), padding = "same")(gen)
  gen = tf.keras.layers.LeakyReLU(alpha = 0.2)(gen)

  gen = tf.keras.layers.Conv2DTranspose(128, (4,4), strides = (2,2), padding = "same")(gen)
  gen = tf.keras.layers.LeakyReLU(alpha = 0.2)(gen)

  # gen = tf.keras.layers.Conv2DTranspose(128, (4,4), strides = (2,2), padding = "same")(gen)
  # gen = tf.keras.layers.LeakyReLU(alpha = 0.2)(gen)

  out_layer = tf.keras.layers.Conv2D(1, (7,7), activation = "tanh", padding = "same")(gen)

  model = tf.keras.models.Model(in_lat, out_layer)
  return model

# %% [markdown]
# Defining GAN

# %%
def define_gan(g_model, d_model):
  d_model.trainable = False

  gan_output = d_model(g_model.output)
  model      = tf.keras.models.Model(g_model.input, gan_output)
  opt        = tf.keras.optimizers.Adam(learning_rate = 0.0002, beta_1 = 0.5)
  model.compile(loss="binary_crossentropy", optimizer=opt)

  return model

# %% [markdown]
# How to generate real samples

# %%
def generate_real_samples():
  # X_AMD    = AMD_data.next()
  # Y_AMD    = np.array([1,0,0,0,0] * X_AMD.shape[0]).reshape(X_AMD.shape[0], -1)
  # X_CSR    = CSR_data.next()
  # Y_CSR    = np.array([0,1,0,0,0] * X_CSR.shape[0]).reshape(X_CSR.shape[0], -1)
  X_DR     = DR_data.next()
  Y_DR     = np.array([1,0,0] * X_DR.shape[0]).reshape(X_DR.shape[0], -1)
  X_MH     = MH_data.next()
  Y_MH     = np.array([0,1,0] * X_MH.shape[0]).reshape(X_MH.shape[0], -1)
  X_NORMAL = NORMAL_data.next()
  Y_NORMAL = np.array([0,0,1] * X_NORMAL.shape[0]).reshape(X_NORMAL.shape[0], -1)

  X       = np.concatenate([ X_DR, X_MH, X_NORMAL])
  labels  = np.concatenate([ Y_DR, Y_MH, Y_NORMAL])
  y       = np.ones((X.shape[0], 1))

  return [X, labels], y

# %% [markdown]
# How to generate fake samples

# %%
def generate_latent_points(latent_dim, n_samples):
  z_input = np.random.randn(latent_dim * n_samples)
  z_input = z_input.reshape(n_samples, latent_dim)
  return z_input

def generate_fake_samples(generator, latent_dim, n_samples):
  z_input = generate_latent_points(latent_dim, n_samples)
  images  = generator.predict(z_input)
  y       = np.zeros((n_samples, 1))
  return images, y

# %% [markdown]
# #Training the Model

# %% [markdown]
# Defining the train function

# %%
def train(g_model, d_model, c_model, gan_model, latent_dim, n_epochs , batch_size):
  bat_per_epo = int(522/(3*batch_size))

  for i in range(bat_per_epo * n_epochs):
    [Xsup_real, ysup_real], y_real = generate_real_samples()
    c_loss, c_acc                  = c_model.train_on_batch(Xsup_real, ysup_real)

    d_loss1        = d_model.train_on_batch(Xsup_real, y_real)
    X_fake, y_fake = generate_fake_samples(g_model, latent_dim, 3 * batch_size)
    d_loss2        = d_model.train_on_batch(X_fake, y_fake)

    X_gan, y_gan = generate_latent_points(latent_dim, 3 * batch_size), np.ones((3 * batch_size, 1))
    g_loss       = gan_model.train_on_batch(X_gan, y_gan)

    print(">%d, c[%.3f,%.0f], d[%.3f,%.3f], g[%.3f]" % (i+1, c_loss, c_acc*100, d_loss1, d_loss2, g_loss))

  return c_model.evaluate(test_data)

# %% [markdown]
# Defining the models and latent dimension

# %%
latent_dim = 150

d_model, c_model = define_discriminator()
g_model          = define_generator(latent_dim)
gan_model        = define_gan(g_model, d_model)

# %% [markdown]
# Loading model weights

# %%
d_model.load_weights('/content/drive/MyDrive/GAN_weights_NEW/saved_model/d_model/w')
c_model.load_weights('/content/drive/MyDrive/GAN_weights_NEW/saved_model/c_model/w')
g_model.load_weights('/content/drive/MyDrive/GAN_weights_NEW/saved_model/g_model/w')
# Out:
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fcd3c06f550> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fcd3c070390>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fcd8263fc10> and <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7fcd42be46d0>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fcd3b1e1f10> and <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fcd8263fc10>).
# WARNING:tensorflow:Inconsistent references when loading the checkpoint into this object graph. Either the Trackable object references in the Python program have changed in an incompatible way, or the checkpoint was generated in an incompatible program.
#
# Two checkpoint references resolved to different objects (<tensorflow.python.keras.layers.core.Dense object at 0x7fcd42b86c90> and <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fcd3acab8d0>).
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-c99405c6fb54> in <module>()
# ----> 1 d_model.load_weights('/content/drive/MyDrive/GAN_weights_NEW/saved_model/d_model/w')
#       2 c_model.load_weights('/content/drive/MyDrive/GAN_weights_NEW/saved_model/c_model/w')
#       3 g_model.load_weights('/content/drive/MyDrive/GAN_weights_NEW/saved_model/g_model/w')
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py in load_weights(self, filepath, by_name, skip_mismatch, options)
#    2295     filepath, save_format = _detect_save_format(filepath)
#    2296     if save_format == 'tf':
# -> 2297       status = self._trackable_saver.restore(filepath, options)
#    2298       if by_name:
#    2299         raise NotImplementedError(
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/training/tracking/util.py in restore(self, save_path, options)
#    1337         options=options)
#    1338     base.CheckpointPosition(
# -> 1339         checkpoint=checkpoint, proto_id=0).restore(self._graph_view.root)
#    1340
#    1341     # Attached dependencies are not attached to the root, so should be restored
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/training/tracking/base.py in restore(self, trackable)
#     256         # This object's correspondence with a checkpointed object is new, so
#     257         # process deferred restorations for it and its dependencies.
# --> 258         restore_ops = trackable._restore_from_checkpoint_position(self)  # pylint: disable=protected-access
#     259         if restore_ops:
#     260           self._checkpoint.new_restore_ops(restore_ops)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/training/tracking/base.py in _restore_from_checkpoint_position(self, checkpoint_position)
#     976     restore_ops.extend(
#     977         current_position.checkpoint.restore_saveables(
# --> 978             tensor_saveables, python_saveables))
#     979     return restore_ops
#     980
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/training/tracking/util.py in restore_saveables(self, tensor_saveables, python_saveables)
#     307              "expecting %s") % (tensor_saveables.keys(), validated_names))
#     308       new_restore_ops = functional_saver.MultiDeviceSaver(
# --> 309           validated_saveables).restore(self.save_path_tensor, self.options)
#     310       if not context.executing_eagerly():
#     311         for name, restore_op in sorted(new_restore_ops.items()):
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/training/saving/functional_saver.py in restore(self, file_prefix, options)
#     337       restore_ops = tf_function_restore()
#     338     else:
# --> 339       restore_ops = restore_fn()
#     340
#     341     for callback in self._after_restore_callbacks:
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/training/saving/functional_saver.py in restore_fn()
#     321       for device, saver in sorted(self._single_device_savers.items()):
#     322         with ops.device(device):
# --> 323           restore_ops.update(saver.restore(file_prefix, options))
#     324
#     325       return restore_ops
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/training/saving/functional_saver.py in restore(self, file_prefix, options)
#     114                                           structured_restored_tensors):
#     115       restore_ops[saveable.name] = saveable.restore(
# --> 116           restored_tensors, restored_shapes=None)
#     117     return restore_ops
#     118
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/training/saving/saveable_object_util.py in restore(self, restored_tensors, restored_shapes)
#     130       restored_tensor = array_ops.identity(restored_tensor)
#     131       return resource_variable_ops.shape_safe_assign_variable_handle(
# --> 132           self.handle_op, self._var_shape, restored_tensor)
#     133
#     134
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/resource_variable_ops.py in shape_safe_assign_variable_handle(handle, shape, value, name)
#     306   with _handle_graph(handle):
#     307     value_tensor = ops.convert_to_tensor(value)
# --> 308   shape.assert_is_compatible_with(value_tensor.shape)
#     309   return gen_resource_variable_ops.assign_variable_op(
#     310       handle, value_tensor, name=name)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/tensor_shape.py in assert_is_compatible_with(self, other)
#    1159     """
#    1160     if not self.is_compatible_with(other):
# -> 1161       raise ValueError("Shapes %s and %s are incompatible" % (self, other))
#    1162
#    1163   def most_specific_compatible_shape(self, other):
#
# ValueError: Shapes (128,) and (14976,) are incompatible

# %% [markdown]
# Training the model and saving the Accuracy and Loss of test data in history

# %%
history = []
best =0

# %%
with open('/content/drive/MyDrive/GAN_weights_NEW/pickle/history.pkl', 'rb') as f:
  history = pickle.load(f)

# %%
c_model.load_weights('/content/drive/MyDrive/GAN_weights_NEW/saved_model/c_model_best/w')

# %%
for i in range(100):
  loss, acc = train(g_model, d_model, c_model, gan_model, latent_dim, n_epochs = 1, batch_size = batch_size)
  if acc > best:
    best = acc
    c_model.save_weights('/content/drive/MyDrive/GAN_weights_NEW/saved_model/c_model_best/w')
  history.append([loss, acc])
# Out:
# Streaming output truncated to the last 5000 lines.
# >17, c[0.318,100], d[0.426,0.529], g[1.004]
# >18, c[0.300,100], d[0.549,0.421], g[0.953]
# >19, c[0.407,83], d[0.521,0.612], g[1.085]
# >20, c[0.253,100], d[0.406,0.573], g[0.928]
# >21, c[0.294,83], d[0.493,0.542], g[0.856]
# >22, c[0.336,100], d[0.531,0.644], g[1.046]
# >23, c[0.317,100], d[0.606,0.580], g[1.052]
# >24, c[0.252,100], d[0.495,0.477], g[1.147]
# >25, c[0.356,83], d[0.535,0.573], g[1.062]
# >26, c[0.261,83], d[0.505,0.787], g[1.064]
# >27, c[0.395,83], d[0.379,0.681], g[0.763]
# >28, c[0.283,83], d[0.417,1.020], g[0.733]
# >29, c[0.330,83], d[0.744,0.784], g[1.253]
# >30, c[0.365,83], d[0.694,0.451], g[1.205]
# >31, c[0.194,100], d[0.956,0.350], g[1.517]
# >32, c[0.619,83], d[1.009,0.277], g[1.283]
# >33, c[0.351,100], d[0.504,0.343], g[1.099]
# >34, c[0.489,67], d[0.889,0.520], g[1.245]
# >35, c[0.278,100], d[0.952,0.466], g[0.864]
# >36, c[0.259,83], d[0.906,0.511], g[1.071]
# >37, c[0.381,83], d[0.850,0.543], g[1.188]
# >38, c[0.419,67], d[0.796,0.542], g[1.248]
# >39, c[0.272,100], d[0.700,0.394], g[0.934]
# >40, c[0.318,83], d[0.753,0.609], g[0.882]
# >41, c[0.325,100], d[0.655,0.646], g[0.952]
# >42, c[0.645,50], d[0.675,0.538], g[1.204]
# >43, c[0.304,100], d[0.926,0.301], g[1.543]
# >44, c[0.444,83], d[0.893,0.615], g[0.970]
# >45, c[0.317,83], d[0.729,0.577], g[1.118]
# >46, c[0.421,67], d[0.693,0.372], g[1.452]
# >47, c[0.378,83], d[0.779,0.388], g[1.161]
# >48, c[0.314,83], d[0.795,0.410], g[1.204]
# >49, c[0.284,100], d[0.703,0.398], g[1.301]
# >50, c[0.297,83], d[0.735,0.471], g[1.260]
# >51, c[0.360,100], d[0.581,0.641], g[1.118]
# >52, c[0.164,100], d[0.548,0.580], g[1.123]
# >53, c[0.271,80], d[0.657,0.526], g[1.158]
# >54, c[0.340,100], d[0.622,0.483], g[0.998]
# >55, c[0.377,83], d[0.828,0.568], g[1.153]
# >56, c[0.312,100], d[0.739,0.486], g[1.128]
# >57, c[0.554,67], d[0.818,0.413], g[1.131]
# >58, c[0.392,83], d[0.722,0.445], g[0.901]
# >59, c[0.284,83], d[0.749,0.373], g[0.950]
# >60, c[0.319,83], d[0.669,0.550], g[1.041]
# >61, c[0.297,100], d[0.702,0.614], g[1.211]
# >62, c[0.371,83], d[0.781,0.452], g[0.989]
# >63, c[0.423,67], d[0.795,0.446], g[0.919]
# >64, c[0.266,100], d[0.768,0.681], g[0.984]
# >65, c[0.344,100], d[0.604,0.589], g[1.024]
# >66, c[0.457,67], d[0.758,0.706], g[1.454]
# >67, c[0.230,100], d[0.745,0.430], g[1.196]
# >68, c[0.377,83], d[0.774,0.341], g[1.256]
# >69, c[0.249,100], d[0.861,0.345], g[1.475]
# >70, c[0.350,100], d[0.591,0.515], g[1.144]
# >71, c[0.153,100], d[0.747,0.371], g[1.080]
# >72, c[0.391,67], d[0.886,0.387], g[0.910]
# >73, c[0.410,83], d[0.670,0.499], g[0.988]
# >74, c[0.338,67], d[0.847,0.544], g[1.034]
# >75, c[0.261,100], d[0.673,0.496], g[1.123]
# >76, c[0.344,67], d[0.590,0.415], g[1.077]
# >77, c[0.267,100], d[0.844,0.403], g[1.167]
# >78, c[0.306,83], d[0.892,0.470], g[1.054]
# >79, c[0.268,100], d[0.484,0.585], g[1.079]
# >80, c[0.373,83], d[0.542,0.492], g[1.155]
# >81, c[0.180,100], d[0.533,0.543], g[1.193]
# >82, c[0.288,100], d[0.545,0.503], g[1.136]
# >83, c[0.390,83], d[0.546,0.483], g[1.140]
# >84, c[0.368,83], d[0.626,0.430], g[0.937]
# >85, c[0.297,83], d[0.559,0.486], g[1.157]
# >86, c[0.342,83], d[0.544,0.476], g[1.169]
# >87, c[0.542,67], d[0.600,0.346], g[1.439]
# 15/15 [==============================] - 0s 21ms/step - loss: 0.4141 - accuracy: 0.9000
# >1, c[0.433,89], d[0.720,0.382], g[1.280]
# >2, c[0.288,83], d[0.719,0.337], g[1.194]
# >3, c[0.258,100], d[0.675,0.545], g[1.113]
# >4, c[0.296,100], d[0.579,0.656], g[1.148]
# >5, c[0.366,100], d[0.572,0.420], g[1.362]
# >6, c[0.239,100], d[0.470,0.339], g[1.192]
# >7, c[0.409,67], d[0.694,0.381], g[1.021]
# >8, c[0.239,100], d[0.742,0.513], g[0.939]
# >9, c[0.419,83], d[0.666,0.510], g[1.002]
# >10, c[0.269,100], d[0.700,0.412], g[1.113]
# >11, c[0.215,100], d[0.630,0.349], g[0.948]
# >12, c[0.324,100], d[0.519,0.549], g[1.222]
# >13, c[0.341,67], d[0.725,0.439], g[1.071]
# >14, c[0.429,67], d[0.549,0.421], g[0.997]
# >15, c[0.234,100], d[0.419,0.597], g[1.215]
# >16, c[0.328,100], d[0.737,0.498], g[0.962]
# >17, c[0.429,83], d[0.643,0.452], g[1.225]
# >18, c[0.424,67], d[0.659,0.500], g[1.151]
# >19, c[0.325,83], d[0.688,0.444], g[1.111]
# >20, c[0.623,50], d[0.588,0.454], g[1.110]
# >21, c[0.380,83], d[0.567,0.412], g[1.078]
# >22, c[0.277,100], d[0.654,0.602], g[1.338]
# >23, c[0.236,100], d[0.746,0.390], g[1.014]
# >24, c[0.235,100], d[0.495,0.534], g[0.984]
# >25, c[0.238,100], d[0.679,0.441], g[1.015]
# >26, c[0.250,100], d[0.424,0.491], g[1.147]
# >27, c[0.406,83], d[0.625,0.458], g[1.122]
# >28, c[0.265,100], d[0.772,0.618], g[1.087]
# >29, c[0.195,100], d[0.586,0.494], g[1.036]
# >30, c[0.357,83], d[0.720,0.531], g[1.096]
# >31, c[0.359,83], d[0.726,0.576], g[1.085]
# >32, c[0.292,83], d[0.489,0.445], g[1.070]
# >33, c[0.325,83], d[0.511,0.563], g[1.045]
# >34, c[0.295,100], d[0.829,0.543], g[1.157]
# >35, c[0.399,83], d[0.571,0.671], g[1.107]
# >36, c[0.375,83], d[0.519,0.532], g[0.941]
# >37, c[0.133,100], d[0.460,0.530], g[1.182]
# >38, c[0.586,50], d[0.560,0.411], g[1.098]
# >39, c[0.248,100], d[0.510,0.517], g[0.978]
# >40, c[0.430,100], d[0.592,0.592], g[0.986]
# >41, c[0.276,100], d[0.737,0.386], g[1.085]
# >42, c[0.217,100], d[0.699,0.563], g[1.120]
# >43, c[0.461,83], d[0.689,0.475], g[1.097]
# >44, c[0.446,67], d[0.593,0.459], g[1.024]
# >45, c[0.262,100], d[0.512,0.419], g[1.058]
# >46, c[0.320,83], d[0.577,0.507], g[1.007]
# >47, c[0.445,67], d[0.565,0.596], g[1.002]
# >48, c[0.219,100], d[0.562,0.502], g[1.134]
# >49, c[0.435,83], d[0.538,0.558], g[1.019]
# >50, c[0.300,83], d[0.501,0.498], g[0.857]
# >51, c[0.370,83], d[0.648,0.399], g[0.952]
# >52, c[0.198,100], d[0.516,0.600], g[0.758]
# >53, c[0.475,50], d[0.695,0.693], g[0.873]
# >54, c[0.280,83], d[0.449,0.548], g[0.883]
# >55, c[0.313,83], d[0.593,0.540], g[0.882]
# >56, c[0.657,50], d[0.524,0.481], g[0.760]
# >57, c[0.300,83], d[0.436,0.661], g[0.867]
# >58, c[0.378,67], d[0.603,0.486], g[0.875]
# >59, c[0.342,83], d[0.544,0.518], g[0.956]
# >60, c[0.458,83], d[0.667,0.624], g[0.940]
# >61, c[0.292,100], d[0.530,0.637], g[0.845]
# >62, c[0.289,100], d[0.545,0.632], g[0.708]
# >63, c[0.371,83], d[0.590,0.565], g[0.887]
# >64, c[0.265,100], d[0.582,0.750], g[0.662]
# >65, c[0.377,83], d[0.640,0.653], g[0.820]
# >66, c[0.316,100], d[0.576,0.667], g[0.929]
# >67, c[0.318,83], d[0.564,0.491], g[0.767]
# >68, c[0.496,50], d[0.626,0.693], g[0.914]
# >69, c[0.292,83], d[0.577,0.649], g[0.889]
# >70, c[0.308,83], d[0.708,0.497], g[0.924]
# >71, c[0.349,67], d[0.679,0.458], g[1.051]
# >72, c[0.393,83], d[0.536,0.543], g[0.745]
# >73, c[0.323,100], d[0.698,0.692], g[0.995]
# >74, c[0.302,83], d[0.687,0.644], g[0.974]
# >75, c[0.163,100], d[0.619,0.505], g[0.878]
# >76, c[0.350,83], d[0.522,0.514], g[0.948]
# >77, c[0.743,67], d[0.594,0.550], g[0.955]
# >78, c[0.560,67], d[0.477,0.546], g[1.035]
# >79, c[0.293,100], d[0.611,0.537], g[1.007]
# >80, c[0.357,83], d[0.670,0.473], g[0.989]
# >81, c[0.318,100], d[0.730,0.578], g[0.942]
# >82, c[0.450,83], d[0.564,0.604], g[1.021]
# >83, c[0.265,100], d[0.622,0.533], g[0.920]
# >84, c[0.401,67], d[0.638,0.638], g[0.944]
# >85, c[0.255,83], d[0.437,0.545], g[0.837]
# >86, c[0.399,83], d[0.453,0.632], g[0.884]
# >87, c[0.360,83], d[0.379,0.627], g[0.979]
# 15/15 [==============================] - 0s 22ms/step - loss: 0.5152 - accuracy: 0.7667
# >1, c[0.487,78], d[0.378,0.689], g[0.939]
# >2, c[0.240,100], d[0.511,0.446], g[0.955]
# >3, c[0.363,83], d[0.590,0.545], g[1.041]
# >4, c[0.232,100], d[0.679,0.581], g[0.751]
# >5, c[0.726,67], d[0.617,0.676], g[0.939]
# >6, c[0.561,50], d[0.713,0.564], g[0.820]
# >7, c[0.332,67], d[0.526,0.625], g[0.891]
# >8, c[0.339,100], d[0.573,0.603], g[0.826]
# >9, c[0.285,83], d[0.539,0.533], g[0.956]
# >10, c[0.231,100], d[0.619,0.440], g[1.135]
# >11, c[0.282,83], d[0.463,0.629], g[0.806]
# >12, c[0.369,67], d[0.664,0.526], g[0.845]
# >13, c[0.417,67], d[0.582,0.703], g[1.072]
# >14, c[0.275,83], d[0.590,0.545], g[1.220]
# >15, c[0.409,83], d[0.877,0.576], g[1.148]
# >16, c[0.284,83], d[0.601,0.446], g[1.180]
# >17, c[0.294,83], d[0.650,0.484], g[1.162]
# >18, c[0.461,67], d[0.516,0.472], g[1.023]
# >19, c[0.325,83], d[0.673,0.486], g[0.921]
# >20, c[0.644,50], d[0.607,0.564], g[0.999]
# >21, c[0.298,83], d[0.568,0.448], g[1.184]
# >22, c[0.204,100], d[0.479,0.494], g[0.969]
# >23, c[0.325,83], d[0.558,0.512], g[1.036]
# >24, c[0.440,83], d[0.708,0.507], g[1.031]
# >25, c[0.279,100], d[0.558,0.477], g[1.036]
# >26, c[0.285,100], d[0.548,0.436], g[0.972]
# >27, c[0.319,100], d[0.532,0.489], g[0.994]
# >28, c[0.457,67], d[0.829,0.506], g[1.016]
# >29, c[0.342,83], d[0.688,0.441], g[1.070]
# >30, c[0.349,100], d[0.563,0.367], g[1.025]
# >31, c[0.329,83], d[0.512,0.483], g[1.009]
# >32, c[0.353,83], d[0.544,0.470], g[0.970]
# >33, c[0.550,67], d[0.367,0.622], g[0.977]
# >34, c[0.207,100], d[0.615,0.583], g[0.774]
# >35, c[0.602,50], d[0.464,0.714], g[0.898]
# >36, c[0.247,83], d[0.369,0.641], g[0.609]
# >37, c[0.226,100], d[0.807,0.705], g[0.514]
# >38, c[0.296,100], d[0.890,0.645], g[0.802]
# >39, c[0.241,83], d[0.646,0.662], g[1.018]
# >40, c[0.496,67], d[0.595,0.588], g[1.017]
# >41, c[0.210,100], d[0.626,0.465], g[0.947]
# >42, c[0.187,100], d[0.647,0.580], g[0.802]
# >43, c[0.265,100], d[0.660,0.600], g[1.036]
# >44, c[0.220,100], d[0.587,0.452], g[1.295]
# >45, c[0.266,100], d[0.780,0.470], g[1.067]
# >46, c[0.516,50], d[0.636,0.534], g[1.063]
# >47, c[0.231,100], d[0.736,0.338], g[1.260]
# >48, c[0.380,83], d[0.710,0.369], g[1.085]
# >49, c[0.276,100], d[0.663,0.441], g[1.074]
# >50, c[0.215,100], d[0.501,0.386], g[1.182]
# >51, c[0.265,100], d[0.656,0.434], g[0.832]
# >52, c[0.264,100], d[0.602,0.470], g[1.169]
# >53, c[0.129,100], d[0.482,0.527], g[0.993]
# >54, c[0.280,100], d[0.507,0.707], g[1.053]
# >55, c[0.446,50], d[0.629,0.535], g[1.003]
# >56, c[0.242,83], d[0.681,0.465], g[1.069]
# >57, c[0.257,100], d[0.525,6.053], g[1.713]
# >58, c[1.153,50], d[0.749,0.331], g[1.174]
# >59, c[1.012,50], d[0.727,0.312], g[1.127]
# >60, c[0.486,67], d[1.011,0.573], g[1.004]
# >61, c[0.466,67], d[0.611,0.954], g[1.699]
# >62, c[0.249,100], d[0.611,0.331], g[1.712]
# >63, c[0.578,50], d[0.866,0.335], g[1.158]
# >64, c[0.216,100], d[0.830,0.509], g[1.291]
# >65, c[0.456,67], d[0.817,1.233], g[1.122]
# >66, c[0.365,83], d[0.566,0.349], g[0.967]
# >67, c[0.367,67], d[0.760,0.457], g[0.557]
# >68, c[0.462,67], d[0.488,0.586], g[0.647]
# >69, c[0.291,100], d[0.860,0.960], g[1.068]
# >70, c[0.417,83], d[0.880,1.702], g[1.645]
# >71, c[0.695,50], d[0.644,0.475], g[1.395]
# >72, c[0.284,100], d[0.621,0.305], g[0.891]
# >73, c[0.403,67], d[0.712,2.715], g[1.217]
# >74, c[0.841,50], d[0.700,0.501], g[2.042]
# >75, c[0.426,80], d[0.801,0.400], g[1.355]
# >76, c[0.338,100], d[0.815,0.400], g[1.577]
# >77, c[0.211,100], d[0.682,0.456], g[1.105]
# >78, c[0.335,83], d[0.605,0.446], g[1.040]
# >79, c[0.303,83], d[0.368,0.364], g[0.876]
# >80, c[0.343,100], d[0.480,0.880], g[0.982]
# >81, c[0.371,83], d[0.659,0.440], g[0.876]
# >82, c[0.379,67], d[0.544,1.302], g[1.135]
# >83, c[0.546,83], d[0.787,0.483], g[0.945]
# >84, c[0.454,67], d[0.923,0.275], g[1.151]
# >85, c[0.350,83], d[0.646,1.476], g[0.882]
# >86, c[0.219,100], d[0.701,1.604], g[0.903]
# >87, c[0.481,83], d[0.427,0.699], g[1.255]
# 15/15 [==============================] - 0s 21ms/step - loss: 0.4169 - accuracy: 0.8333
# >1, c[0.438,78], d[0.843,0.614], g[1.109]
# >2, c[0.473,67], d[0.796,0.466], g[0.951]
# >3, c[0.564,83], d[0.465,0.480], g[0.967]
# >4, c[0.417,83], d[0.411,0.622], g[0.825]
# >5, c[0.274,100], d[0.464,0.827], g[0.877]
# >6, c[0.417,83], d[0.434,0.589], g[0.842]
# >7, c[0.522,83], d[0.466,0.507], g[0.822]
# >8, c[0.513,67], d[0.583,0.557], g[1.050]
# >9, c[0.464,67], d[0.617,0.579], g[1.001]
# >10, c[0.359,83], d[0.567,0.555], g[0.737]
# >11, c[0.343,100], d[0.322,0.715], g[0.770]
# >12, c[0.534,67], d[0.176,0.907], g[0.876]
# >13, c[0.204,100], d[0.333,0.980], g[0.996]
# >14, c[0.325,100], d[0.354,0.851], g[0.668]
# >15, c[0.437,67], d[0.464,0.416], g[0.834]
# >16, c[0.497,83], d[0.305,1.821], g[0.782]
# >17, c[0.289,83], d[0.386,0.531], g[1.283]
# >18, c[0.332,100], d[0.523,0.834], g[1.271]
# >19, c[0.486,50], d[0.677,1.887], g[1.232]
# >20, c[0.943,33], d[0.532,0.976], g[1.459]
# >21, c[0.241,100], d[0.481,0.410], g[1.012]
# >22, c[0.315,100], d[0.401,2.006], g[1.270]
# >23, c[0.424,83], d[0.479,0.773], g[1.488]
# >24, c[0.539,83], d[0.893,0.374], g[1.173]
# >25, c[0.377,100], d[0.420,0.438], g[0.918]
# >26, c[0.184,100], d[0.394,0.863], g[1.045]
# >27, c[0.399,83], d[0.417,0.403], g[1.052]
# >28, c[0.310,100], d[0.372,0.842], g[0.951]
# >29, c[0.430,67], d[0.433,0.552], g[1.025]
# >30, c[0.397,83], d[0.425,1.097], g[1.239]
# >31, c[0.359,83], d[0.646,0.338], g[1.272]
# >32, c[0.228,100], d[0.450,0.677], g[1.237]
# >33, c[0.480,83], d[0.449,1.713], g[1.253]
# >34, c[0.510,67], d[0.524,0.570], g[1.013]
# >35, c[0.344,83], d[0.333,0.363], g[1.284]
# >36, c[0.397,83], d[0.480,0.553], g[1.521]
# >37, c[0.788,60], d[0.467,0.373], g[1.175]
# >38, c[0.587,83], d[0.266,0.463], g[1.146]
# >39, c[0.332,100], d[0.532,0.479], g[1.172]
# >40, c[0.197,100], d[0.408,0.449], g[1.263]
# >41, c[0.281,83], d[0.360,0.365], g[0.977]
# >42, c[0.396,67], d[0.359,0.378], g[0.992]
# >43, c[0.282,83], d[0.581,0.462], g[0.966]
# >44, c[0.253,100], d[0.542,0.500], g[1.094]
# >45, c[0.244,100], d[0.577,0.480], g[1.038]
# >46, c[0.453,50], d[0.603,0.608], g[1.090]
# >47, c[0.281,100], d[0.329,0.460], g[1.186]
# >48, c[0.214,100], d[0.337,0.369], g[1.263]
# >49, c[0.456,67], d[0.471,0.361], g[1.195]
# >50, c[0.347,83], d[0.664,0.486], g[0.858]
# >51, c[0.353,83], d[0.257,0.722], g[0.737]
# >52, c[0.210,100], d[0.551,0.665], g[1.332]
# >53, c[0.391,67], d[0.516,0.514], g[1.102]
# >54, c[0.353,100], d[0.550,0.423], g[1.188]
# >55, c[0.389,83], d[0.549,0.400], g[1.376]
# >56, c[0.356,83], d[0.447,0.676], g[0.988]
# >57, c[0.315,100], d[0.527,2.408], g[2.014]
# >58, c[0.295,83], d[0.527,0.954], g[2.037]
# >59, c[0.548,67], d[0.792,0.175], g[1.309]
# >60, c[0.311,100], d[0.488,0.186], g[2.191]
# >61, c[0.464,83], d[0.446,0.716], g[1.943]
# >62, c[0.213,100], d[0.714,1.379], g[1.561]
# >63, c[0.370,83], d[0.741,1.036], g[4.118]
# >64, c[0.715,50], d[1.283,0.667], g[1.985]
# >65, c[0.482,83], d[0.725,0.193], g[2.381]
# >66, c[0.398,100], d[0.898,0.101], g[2.348]
# >67, c[0.335,100], d[0.947,0.141], g[2.381]
# >68, c[0.504,67], d[0.939,0.261], g[1.757]
# >69, c[0.397,83], d[0.644,0.335], g[1.376]
# >70, c[0.316,100], d[0.609,0.344], g[1.076]
# >71, c[0.292,100], d[0.538,0.491], g[1.015]
# >72, c[0.332,83], d[0.701,0.725], g[0.837]
# >73, c[0.271,83], d[0.682,0.700], g[1.105]
# >74, c[0.331,83], d[0.581,0.593], g[0.895]
# >75, c[0.620,67], d[0.465,0.776], g[0.842]
# >76, c[0.511,67], d[0.713,0.660], g[1.017]
# >77, c[0.333,83], d[0.530,0.496], g[1.146]
# >78, c[0.518,67], d[0.829,0.506], g[0.839]
# >79, c[0.311,100], d[0.499,0.888], g[1.034]
# >80, c[0.336,83], d[0.778,0.581], g[1.073]
# >81, c[0.346,67], d[0.473,0.547], g[1.115]
# >82, c[0.261,100], d[0.420,0.403], g[0.878]
# >83, c[0.445,83], d[0.545,0.358], g[1.135]
# >84, c[0.221,100], d[0.544,0.600], g[0.916]
# >85, c[0.432,67], d[0.674,0.599], g[0.790]
# >86, c[0.249,100], d[0.338,0.872], g[0.823]
# >87, c[0.245,83], d[0.621,0.561], g[0.982]
# 15/15 [==============================] - 0s 22ms/step - loss: 0.4455 - accuracy: 0.9000
# >1, c[0.419,92], d[0.667,0.558], g[1.079]
# >2, c[0.140,100], d[0.637,0.694], g[0.858]
# >3, c[0.401,67], d[0.678,0.593], g[1.242]
# >4, c[0.244,83], d[0.447,0.464], g[1.019]
# >5, c[0.457,67], d[0.890,0.918], g[0.895]
# >6, c[0.456,67], d[0.853,0.553], g[1.184]
# >7, c[0.395,67], d[0.690,0.448], g[1.281]
# >8, c[0.246,100], d[0.836,0.458], g[1.280]
# >9, c[0.509,67], d[1.053,0.387], g[1.193]
# >10, c[0.568,83], d[1.029,0.535], g[1.084]
# >11, c[0.460,67], d[0.836,0.615], g[1.021]
# >12, c[0.178,100], d[0.631,0.354], g[0.925]
# >13, c[0.331,100], d[0.689,0.626], g[0.994]
# >14, c[0.410,67], d[0.719,0.587], g[1.208]
# >15, c[0.292,83], d[0.981,0.410], g[0.959]
# >16, c[0.195,100], d[0.597,0.568], g[1.145]
# >17, c[0.439,67], d[0.797,0.448], g[1.477]
# >18, c[0.201,100], d[0.798,0.584], g[1.154]
# >19, c[0.286,100], d[0.671,0.508], g[1.211]
# >20, c[0.544,67], d[0.775,0.444], g[1.086]
# >21, c[0.153,100], d[0.601,0.493], g[1.137]
# >22, c[0.410,83], d[0.687,0.495], g[1.002]
# >23, c[0.254,100], d[0.698,0.552], g[0.967]
# >24, c[0.399,100], d[0.663,0.575], g[0.863]
# >25, c[0.530,67], d[0.880,0.581], g[0.929]
# >26, c[0.594,83], d[0.548,0.457], g[0.963]
# >27, c[0.180,100], d[0.789,0.441], g[1.037]
# >28, c[0.237,100], d[0.640,0.448], g[0.953]
# >29, c[0.279,83], d[0.511,0.665], g[1.152]
# >30, c[0.441,83], d[0.770,0.434], g[1.102]
# >31, c[0.335,83], d[0.639,0.643], g[1.027]
# >32, c[0.321,83], d[0.548,0.570], g[1.044]
# >33, c[0.618,67], d[0.436,0.509], g[1.131]
# >34, c[0.396,83], d[0.564,0.482], g[1.046]
# >35, c[0.184,100], d[0.989,0.457], g[0.968]
# >36, c[0.336,83], d[0.702,0.662], g[1.005]
# >37, c[0.451,67], d[0.619,0.478], g[1.171]
# >38, c[0.290,100], d[0.667,0.364], g[0.929]
# >39, c[0.595,67], d[0.659,0.507], g[1.147]
# >40, c[0.417,67], d[0.472,0.464], g[1.106]
# >41, c[0.469,67], d[0.494,0.594], g[1.106]
# >42, c[0.260,100], d[0.714,0.394], g[0.926]
# >43, c[0.314,83], d[0.558,0.449], g[0.946]
# >44, c[0.457,67], d[0.741,0.511], g[0.992]
# >45, c[0.456,67], d[0.667,0.524], g[0.949]
# >46, c[0.292,100], d[0.496,0.401], g[0.910]
# >47, c[0.567,83], d[0.697,0.573], g[1.030]
# >48, c[0.272,100], d[0.526,0.485], g[0.931]
# >49, c[0.320,83], d[0.590,0.553], g[0.906]
# >50, c[0.182,100], d[0.754,0.559], g[1.234]
# >51, c[0.331,83], d[0.695,0.490], g[1.159]
# >52, c[0.373,83], d[0.817,0.524], g[0.945]
# >53, c[0.189,100], d[0.565,0.432], g[1.223]
# >54, c[0.449,83], d[0.693,0.330], g[0.960]
# >55, c[0.257,100], d[0.656,0.497], g[1.165]
# >56, c[0.616,50], d[0.745,0.494], g[1.216]
# >57, c[0.246,100], d[0.620,0.515], g[1.211]
# >58, c[0.388,83], d[0.622,0.414], g[1.044]
# >59, c[0.218,100], d[0.688,0.386], g[1.275]
# >60, c[0.313,100], d[0.648,0.518], g[1.243]
# >61, c[0.266,100], d[0.826,0.629], g[1.121]
# >62, c[0.294,100], d[0.540,0.543], g[1.128]
# >63, c[0.250,100], d[0.512,0.388], g[1.071]
# >64, c[0.312,100], d[0.657,0.542], g[1.076]
# >65, c[0.397,83], d[0.603,0.547], g[1.025]
# >66, c[0.254,83], d[0.495,0.506], g[1.106]
# >67, c[0.373,83], d[0.730,0.475], g[1.258]
# >68, c[0.235,100], d[0.863,0.584], g[1.091]
# >69, c[0.286,83], d[0.912,0.454], g[1.067]
# >70, c[0.484,83], d[0.731,0.523], g[1.115]
# >71, c[0.434,83], d[0.597,0.391], g[1.108]
# >72, c[0.294,100], d[0.581,0.477], g[1.266]
# >73, c[0.216,100], d[0.680,0.399], g[1.003]
# >74, c[0.260,83], d[0.604,0.513], g[1.114]
# >75, c[0.425,83], d[0.717,0.434], g[0.961]
# >76, c[0.276,100], d[0.571,0.438], g[1.062]
# >77, c[0.299,100], d[0.607,0.470], g[0.905]
# >78, c[0.184,100], d[0.623,0.487], g[1.044]
# >79, c[0.376,83], d[0.596,0.475], g[0.839]
# >80, c[0.427,83], d[0.698,0.593], g[1.054]
# >81, c[0.555,50], d[0.612,0.570], g[0.884]
# >82, c[0.457,67], d[0.703,0.493], g[0.962]
# >83, c[0.289,100], d[0.708,0.506], g[1.005]
# >84, c[0.336,100], d[0.385,0.487], g[0.960]
# >85, c[0.316,83], d[0.670,0.459], g[1.039]
# >86, c[0.307,83], d[0.515,0.514], g[0.897]
# >87, c[0.315,83], d[0.651,0.544], g[1.239]
# 15/15 [==============================] - 0s 22ms/step - loss: 0.4556 - accuracy: 0.8667
# >1, c[0.432,89], d[0.469,0.513], g[1.158]
# >2, c[0.179,100], d[0.538,0.506], g[1.040]
# >3, c[0.226,100], d[0.758,0.666], g[1.145]
# >4, c[0.235,100], d[0.636,0.520], g[1.012]
# >5, c[0.318,83], d[0.541,0.483], g[1.042]
# >6, c[0.433,83], d[0.532,0.423], g[1.014]
# >7, c[0.271,100], d[0.608,0.482], g[0.902]
# >8, c[0.213,100], d[0.729,0.445], g[0.922]
# >9, c[0.519,67], d[0.655,0.546], g[0.923]
# >10, c[0.343,80], d[0.549,0.621], g[0.985]
# >11, c[0.289,100], d[0.450,0.562], g[1.044]
# >12, c[0.376,67], d[0.599,0.506], g[1.168]
# >13, c[0.338,83], d[0.642,0.408], g[1.104]
# >14, c[0.335,83], d[0.679,0.616], g[0.837]
# >15, c[0.396,67], d[0.687,0.586], g[1.044]
# >16, c[0.301,100], d[0.751,0.430], g[1.007]
# >17, c[0.218,100], d[0.626,0.495], g[0.952]
# >18, c[0.171,100], d[0.577,0.402], g[0.920]
# >19, c[0.289,83], d[0.610,0.516], g[1.013]
# >20, c[0.302,100], d[0.570,0.568], g[1.120]
# >21, c[0.301,100], d[0.644,0.471], g[1.102]
# >22, c[0.317,83], d[0.476,0.490], g[0.980]
# >23, c[0.441,67], d[0.580,0.525], g[0.912]
# >24, c[0.379,83], d[0.593,0.562], g[0.931]
# >25, c[0.710,50], d[0.713,0.445], g[0.856]
# >26, c[0.268,83], d[0.527,0.530], g[1.115]
# >27, c[0.304,100], d[0.697,0.548], g[1.083]
# >28, c[0.408,83], d[0.616,0.438], g[1.029]
# >29, c[0.288,100], d[0.562,0.458], g[1.115]
# >30, c[0.460,67], d[0.663,0.502], g[1.076]
# >31, c[0.155,100], d[0.639,0.520], g[0.911]
# >32, c[0.314,83], d[0.717,0.417], g[1.112]
# >33, c[0.276,100], d[0.535,0.530], g[1.070]
# >34, c[0.307,100], d[0.660,0.558], g[0.944]
# >35, c[0.273,100], d[0.545,0.519], g[1.061]
# >36, c[0.309,83], d[0.677,0.616], g[0.832]
# >37, c[0.446,67], d[0.565,0.458], g[0.881]
# >38, c[0.453,67], d[0.580,0.699], g[0.982]
# >39, c[0.416,67], d[0.534,0.609], g[0.993]
# >40, c[0.365,83], d[0.812,0.562], g[0.970]
# >41, c[0.322,83], d[0.650,0.496], g[0.954]
# >42, c[0.373,67], d[0.485,0.483], g[0.992]
# >43, c[0.410,83], d[0.645,0.384], g[1.045]
# >44, c[0.463,83], d[0.571,0.436], g[1.057]
# >45, c[0.137,100], d[0.652,0.499], g[1.053]
# >46, c[0.330,100], d[0.477,0.443], g[1.065]
# >47, c[0.353,83], d[0.677,0.503], g[0.946]
# >48, c[0.258,83], d[0.559,0.524], g[1.138]
# >49, c[0.312,83], d[0.594,0.455], g[1.154]
# >50, c[0.447,67], d[0.489,0.444], g[1.088]
# >51, c[0.519,67], d[0.459,0.428], g[1.253]
# >52, c[0.423,67], d[0.651,0.495], g[1.001]
# >53, c[0.380,83], d[0.744,0.606], g[1.163]
# >54, c[0.227,100], d[0.576,0.597], g[1.026]
# >55, c[0.304,83], d[0.508,0.455], g[1.048]
# >56, c[0.179,100], d[0.431,0.493], g[1.048]
# >57, c[0.216,100], d[0.458,0.531], g[1.039]
# >58, c[0.400,67], d[0.745,0.518], g[0.975]
# >59, c[0.513,40], d[0.552,0.484], g[1.056]
# >60, c[0.208,100], d[0.495,0.465], g[0.912]
# >61, c[0.346,83], d[0.600,0.437], g[1.123]
# >62, c[0.302,83], d[0.581,0.475], g[0.921]
# >63, c[0.330,83], d[0.645,0.393], g[0.919]
# >64, c[0.292,83], d[0.822,0.507], g[0.986]
# >65, c[0.369,83], d[0.537,0.506], g[0.894]
# >66, c[0.307,100], d[0.706,0.568], g[0.966]
# >67, c[0.289,100], d[0.549,0.599], g[1.092]
# >68, c[0.421,83], d[0.533,0.403], g[0.955]
# >69, c[0.227,100], d[0.463,0.522], g[1.141]
# >70, c[0.488,67], d[0.540,0.710], g[1.001]
# >71, c[0.267,100], d[0.639,0.502], g[1.109]
# >72, c[0.281,83], d[0.649,0.422], g[1.108]
# >73, c[0.289,100], d[0.663,0.472], g[1.029]
# >74, c[0.350,83], d[0.444,0.433], g[1.091]
# >75, c[0.299,83], d[0.543,0.497], g[1.033]
# >76, c[0.563,50], d[0.578,0.492], g[1.118]
# >77, c[0.245,100], d[0.675,0.432], g[0.871]
# >78, c[0.535,83], d[0.817,0.481], g[1.021]
# >79, c[0.439,83], d[0.585,0.575], g[0.833]
# >80, c[0.321,83], d[0.694,0.544], g[1.118]
# >81, c[0.580,67], d[0.535,0.531], g[0.901]
# >82, c[0.623,67], d[0.588,0.520], g[0.938]
# >83, c[0.220,100], d[0.480,0.551], g[0.957]
# >84, c[0.294,83], d[0.605,0.555], g[0.989]
# >85, c[0.479,83], d[0.458,0.673], g[0.861]
# >86, c[0.370,83], d[0.578,0.473], g[0.919]
# >87, c[0.282,83], d[0.601,0.410], g[1.010]
# 15/15 [==============================] - 0s 22ms/step - loss: 0.4060 - accuracy: 0.9000
# >1, c[0.410,89], d[0.622,0.529], g[0.898]
# >2, c[0.444,67], d[0.549,0.475], g[0.909]
# >3, c[0.394,83], d[0.546,0.576], g[0.956]
# >4, c[0.166,100], d[0.605,0.439], g[1.039]
# >5, c[0.420,67], d[0.674,0.450], g[0.822]
# >6, c[0.273,83], d[0.643,0.569], g[0.945]
# >7, c[0.358,83], d[0.783,0.549], g[0.961]
# >8, c[0.382,83], d[0.639,0.463], g[0.934]
# >9, c[0.325,83], d[0.450,0.420], g[0.929]
# >10, c[0.396,67], d[0.547,0.584], g[0.961]
# >11, c[0.391,67], d[0.444,0.556], g[1.039]
# >12, c[0.159,100], d[0.547,0.592], g[1.030]
# >13, c[0.280,100], d[0.509,0.575], g[0.765]
# >14, c[0.252,83], d[0.482,0.472], g[0.969]
# >15, c[0.447,67], d[0.724,0.510], g[0.775]
# >16, c[0.375,83], d[0.640,0.632], g[0.927]
# >17, c[0.343,83], d[0.680,0.454], g[0.976]
# >18, c[0.306,83], d[0.624,0.551], g[0.936]
# >19, c[0.247,100], d[0.553,0.562], g[1.035]
# >20, c[0.161,100], d[0.438,0.513], g[0.946]
# >21, c[0.274,80], d[0.735,0.589], g[0.760]
# >22, c[0.364,83], d[0.786,0.581], g[0.970]
# >23, c[0.386,83], d[0.636,0.586], g[0.884]
# >24, c[0.268,100], d[0.591,0.637], g[0.897]
# >25, c[0.290,100], d[0.558,0.704], g[0.891]
# >26, c[0.521,67], d[0.521,0.632], g[1.175]
# >27, c[0.350,100], d[0.497,0.471], g[1.389]
# >28, c[0.432,83], d[0.693,0.409], g[1.291]
# >29, c[0.294,83], d[0.750,0.398], g[1.302]
# >30, c[0.323,83], d[0.674,0.382], g[1.322]
# >31, c[0.295,100], d[0.575,0.396], g[1.149]
# >32, c[0.480,50], d[0.638,0.425], g[1.079]
# >33, c[0.357,83], d[0.804,0.490], g[1.129]
# >34, c[0.195,100], d[0.554,0.555], g[0.901]
# >35, c[0.407,83], d[0.549,0.569], g[1.138]
# >36, c[0.374,100], d[0.543,0.460], g[0.726]
# >37, c[0.373,67], d[0.828,0.595], g[1.093]
# >38, c[0.333,100], d[0.642,0.526], g[1.045]
# >39, c[0.175,100], d[0.472,0.615], g[0.966]
# >40, c[0.340,83], d[0.406,0.496], g[0.942]
# >41, c[0.343,67], d[0.715,0.479], g[1.059]
# >42, c[0.328,83], d[0.379,0.367], g[0.939]
# >43, c[0.325,67], d[0.581,0.585], g[1.006]
# >44, c[0.182,100], d[0.658,0.619], g[0.934]
# >45, c[0.269,100], d[0.542,0.520], g[1.062]
# >46, c[0.163,100], d[0.518,0.423], g[1.018]
# >47, c[0.260,100], d[0.746,0.488], g[0.971]
# >48, c[0.425,83], d[0.514,0.459], g[1.083]
# >49, c[0.371,67], d[0.581,0.436], g[0.988]
# >50, c[0.225,100], d[0.649,0.487], g[0.933]
# >51, c[0.264,100], d[0.533,0.618], g[0.761]
# >52, c[0.541,67], d[0.610,0.564], g[0.978]
# >53, c[0.457,67], d[0.545,0.469], g[0.879]
# >54, c[0.269,100], d[0.559,0.397], g[0.986]
# >55, c[0.251,100], d[0.689,0.589], g[0.909]
# >56, c[0.275,100], d[0.539,0.516], g[0.887]
# >57, c[0.269,100], d[0.496,0.564], g[0.870]
# >58, c[0.278,100], d[0.614,0.442], g[0.923]
# >59, c[0.343,83], d[0.670,0.548], g[1.009]
# >60, c[0.397,67], d[0.671,0.460], g[1.108]
# >61, c[0.299,100], d[0.563,0.561], g[1.002]
# >62, c[0.338,83], d[0.863,0.533], g[0.994]
# >63, c[0.250,100], d[0.466,0.521], g[0.962]
# >64, c[0.225,100], d[0.699,0.643], g[1.027]
# >65, c[0.259,100], d[0.654,0.508], g[1.008]
# >66, c[0.556,83], d[0.640,0.438], g[0.964]
# >67, c[0.265,100], d[0.481,0.562], g[0.981]
# >68, c[0.426,67], d[0.605,0.458], g[0.914]
# >69, c[0.250,83], d[0.504,0.577], g[0.918]
# >70, c[0.281,80], d[0.373,0.416], g[1.000]
# >71, c[0.699,67], d[0.651,0.497], g[0.980]
# >72, c[0.264,100], d[0.469,0.556], g[0.933]
# >73, c[0.267,100], d[0.580,0.471], g[0.985]
# >74, c[0.259,100], d[0.399,0.667], g[1.198]
# >75, c[0.351,83], d[0.464,0.441], g[1.095]
# >76, c[0.134,100], d[0.589,0.379], g[1.123]
# >77, c[0.272,100], d[0.720,0.505], g[0.992]
# >78, c[0.280,83], d[0.589,0.563], g[1.048]
# >79, c[0.433,83], d[0.685,0.604], g[1.066]
# >80, c[0.219,83], d[0.613,0.442], g[1.032]
# >81, c[0.309,83], d[0.416,0.438], g[1.193]
# >82, c[0.411,67], d[0.931,0.386], g[1.079]
# >83, c[0.212,100], d[0.464,0.436], g[1.119]
# >84, c[0.274,100], d[0.463,0.430], g[1.037]
# >85, c[0.257,100], d[0.494,0.404], g[1.178]
# >86, c[0.285,100], d[0.726,0.492], g[0.943]
# >87, c[0.307,67], d[0.451,0.364], g[0.910]
# 15/15 [==============================] - 0s 23ms/step - loss: 0.5083 - accuracy: 0.7667
# >1, c[0.479,81], d[0.565,0.509], g[1.161]
# >2, c[0.229,100], d[0.558,0.579], g[0.991]
# >3, c[0.406,83], d[0.470,0.386], g[1.171]
# >4, c[0.194,100], d[0.572,0.431], g[1.096]
# >5, c[0.307,83], d[0.476,0.393], g[1.057]
# >6, c[0.328,83], d[0.729,0.578], g[1.265]
# >7, c[0.283,83], d[0.572,0.545], g[1.087]
# >8, c[0.409,67], d[0.671,0.659], g[0.989]
# >9, c[0.452,83], d[0.496,0.898], g[1.149]
# >10, c[0.442,67], d[0.574,0.509], g[1.059]
# >11, c[0.285,83], d[0.654,0.524], g[0.960]
# >12, c[0.284,83], d[0.497,0.720], g[0.948]
# >13, c[0.333,83], d[0.584,0.358], g[1.193]
# >14, c[0.257,100], d[0.377,0.370], g[1.753]
# >15, c[0.270,100], d[0.638,0.370], g[1.424]
# >16, c[0.431,83], d[0.536,0.439], g[1.366]
# >17, c[0.415,83], d[0.593,0.405], g[1.208]
# >18, c[0.199,100], d[0.446,0.423], g[1.133]
# >19, c[0.295,83], d[0.620,0.410], g[1.209]
# >20, c[0.230,100], d[0.472,0.496], g[0.875]
# >21, c[0.285,83], d[0.687,0.476], g[0.934]
# >22, c[0.437,83], d[0.622,0.555], g[0.953]
# >23, c[0.279,83], d[0.490,0.470], g[1.071]
# >24, c[0.280,83], d[0.596,0.404], g[1.099]
# >25, c[0.244,100], d[0.759,0.403], g[0.995]
# >26, c[0.292,83], d[0.465,0.599], g[1.375]
# >27, c[0.308,100], d[0.440,0.368], g[1.611]
# >28, c[0.199,100], d[0.788,0.417], g[1.200]
# >29, c[0.297,100], d[0.362,0.283], g[1.198]
# >30, c[0.285,83], d[0.594,0.436], g[1.183]
# >31, c[0.452,83], d[0.414,0.425], g[1.052]
# >32, c[0.204,100], d[0.605,0.483], g[1.130]
# >33, c[0.291,100], d[0.758,0.517], g[0.949]
# >34, c[0.245,83], d[0.496,0.510], g[1.009]
# >35, c[0.297,83], d[0.417,0.503], g[0.736]
# >36, c[0.342,83], d[0.599,0.961], g[0.813]
# >37, c[0.370,83], d[0.531,0.866], g[0.579]
# >38, c[0.222,100], d[0.583,0.774], g[0.641]
# >39, c[0.237,100], d[0.685,0.991], g[1.085]
# >40, c[0.439,83], d[0.935,0.556], g[1.003]
# >41, c[0.379,67], d[0.711,0.709], g[0.910]
# >42, c[0.288,100], d[0.711,0.514], g[0.758]
# >43, c[0.470,67], d[0.708,0.701], g[0.992]
# >44, c[0.265,83], d[0.652,0.583], g[1.046]
# >45, c[0.258,100], d[0.845,0.532], g[0.889]
# >46, c[0.507,83], d[0.738,0.445], g[1.313]
# >47, c[0.253,100], d[1.207,0.498], g[1.323]
# >48, c[0.368,83], d[0.633,0.402], g[0.742]
# >49, c[0.348,83], d[0.524,0.530], g[0.642]
# >50, c[0.356,83], d[0.964,0.757], g[0.962]
# >51, c[0.320,83], d[0.701,0.544], g[0.988]
# >52, c[0.433,83], d[0.802,0.544], g[0.914]
# >53, c[0.343,83], d[0.779,0.586], g[1.404]
# >54, c[0.311,83], d[0.751,0.441], g[0.813]
# >55, c[0.236,83], d[0.564,0.492], g[1.052]
# >56, c[0.300,83], d[0.878,0.451], g[0.929]
# >57, c[0.395,83], d[0.823,0.510], g[0.756]
# >58, c[0.208,100], d[0.776,0.558], g[0.753]
# >59, c[0.294,100], d[0.563,0.657], g[0.917]
# >60, c[0.323,83], d[0.881,0.710], g[0.900]
# >61, c[0.249,100], d[0.702,0.622], g[0.845]
# >62, c[0.438,67], d[0.605,0.559], g[0.892]
# >63, c[0.238,100], d[0.831,0.449], g[0.865]
# >64, c[0.272,83], d[0.924,0.693], g[0.783]
# >65, c[0.234,100], d[0.613,0.809], g[1.027]
# >66, c[0.152,100], d[0.782,0.706], g[1.061]
# >67, c[0.515,67], d[0.781,0.521], g[1.131]
# >68, c[0.512,67], d[0.784,0.360], g[1.097]
# >69, c[0.351,83], d[0.831,0.500], g[1.283]
# >70, c[0.426,67], d[0.679,0.428], g[1.058]
# >71, c[0.144,100], d[0.613,0.531], g[1.264]
# >72, c[0.229,100], d[0.841,0.418], g[1.134]
# >73, c[0.333,83], d[0.942,0.598], g[0.915]
# >74, c[0.443,83], d[0.744,0.545], g[1.042]
# >75, c[0.217,100], d[0.737,0.516], g[0.826]
# >76, c[0.415,83], d[0.791,0.648], g[0.925]
# >77, c[0.331,100], d[0.703,0.657], g[1.134]
# >78, c[0.291,100], d[0.768,0.422], g[1.186]
# >79, c[0.275,100], d[0.932,0.627], g[0.932]
# >80, c[0.340,83], d[0.960,0.586], g[1.337]
# >81, c[0.383,80], d[0.768,0.392], g[1.029]
# >82, c[0.461,83], d[0.729,0.488], g[1.082]
# >83, c[0.332,67], d[0.860,0.490], g[1.079]
# >84, c[0.388,83], d[0.797,0.408], g[1.050]
# >85, c[0.654,50], d[0.681,0.436], g[1.072]
# >86, c[0.393,67], d[0.848,0.520], g[0.996]
# >87, c[0.488,50], d[0.641,0.643], g[0.993]
# 15/15 [==============================] - 0s 21ms/step - loss: 0.5208 - accuracy: 0.8333
# >1, c[0.490,83], d[0.751,0.417], g[0.896]
# >2, c[0.336,83], d[0.636,0.525], g[1.028]
# >3, c[0.473,83], d[0.564,0.479], g[0.882]
# >4, c[0.239,83], d[0.619,0.652], g[1.024]
# >5, c[0.373,67], d[0.619,0.487], g[0.985]
# >6, c[0.488,67], d[0.572,0.517], g[0.976]
# >7, c[0.596,67], d[0.680,0.568], g[0.809]
# >8, c[0.420,83], d[0.854,0.643], g[0.798]
# >9, c[0.335,83], d[0.573,0.543], g[0.792]
# >10, c[0.370,100], d[0.565,0.490], g[0.935]
# >11, c[0.360,83], d[0.566,0.686], g[0.995]
# >12, c[0.346,67], d[0.685,0.660], g[1.186]
# >13, c[0.251,100], d[0.677,0.559], g[1.021]
# >14, c[0.425,83], d[0.650,0.494], g[0.939]
# >15, c[0.385,83], d[0.637,0.532], g[1.077]
# >16, c[0.153,100], d[0.675,0.519], g[0.847]
# >17, c[0.407,83], d[0.727,0.553], g[0.979]
# >18, c[0.314,83], d[0.624,0.505], g[0.920]
# >19, c[0.239,100], d[0.632,0.501], g[0.987]
# >20, c[0.358,67], d[0.686,0.523], g[1.102]
# >21, c[0.358,83], d[0.715,0.588], g[1.002]
# >22, c[0.326,100], d[0.615,0.427], g[1.095]
# >23, c[0.197,100], d[0.686,0.469], g[1.001]
# >24, c[0.216,100], d[0.560,0.389], g[0.965]
# >25, c[0.382,83], d[0.580,0.473], g[0.995]
# >26, c[0.242,83], d[0.580,0.563], g[1.101]
# >27, c[0.224,100], d[0.664,0.510], g[1.092]
# >28, c[0.754,67], d[0.737,0.565], g[1.101]
# >29, c[0.218,100], d[0.675,0.481], g[0.869]
# >30, c[0.280,100], d[0.584,0.403], g[0.981]
# >31, c[0.347,100], d[0.719,0.388], g[1.310]
# >32, c[0.261,100], d[0.605,0.453], g[1.103]
# >33, c[0.342,83], d[0.673,0.501], g[1.114]
# >34, c[0.238,100], d[0.531,0.384], g[1.341]
# >35, c[0.293,100], d[0.584,0.382], g[1.159]
# >36, c[0.327,83], d[0.623,0.435], g[1.303]
# >37, c[0.445,67], d[0.542,0.410], g[1.062]
# >38, c[0.212,100], d[0.679,0.426], g[1.056]
# >39, c[0.368,83], d[0.581,0.534], g[1.096]
# >40, c[0.439,67], d[0.465,0.553], g[1.116]
# >41, c[0.390,83], d[0.553,0.450], g[1.054]
# >42, c[0.485,67], d[0.615,0.502], g[1.103]
# >43, c[0.426,80], d[0.469,0.415], g[1.017]
# >44, c[0.376,67], d[0.584,0.439], g[1.108]
# >45, c[0.314,100], d[0.557,0.416], g[0.997]
# >46, c[0.501,67], d[0.580,0.422], g[0.861]
# >47, c[0.228,100], d[0.557,0.534], g[1.237]
# >48, c[0.442,83], d[0.502,0.355], g[0.912]
# >49, c[0.339,83], d[0.647,0.532], g[1.084]
# >50, c[0.247,100], d[0.606,0.489], g[1.024]
# >51, c[0.317,100], d[0.671,0.483], g[1.166]
# >52, c[0.424,83], d[0.534,0.472], g[1.246]
# >53, c[0.180,100], d[0.572,0.407], g[1.078]
# >54, c[0.442,83], d[0.626,0.502], g[1.141]
# >55, c[0.376,83], d[0.486,0.333], g[1.101]
# >56, c[0.336,83], d[0.582,0.494], g[1.058]
# >57, c[0.221,100], d[0.517,0.408], g[0.961]
# >58, c[0.561,33], d[0.491,0.484], g[1.193]
# >59, c[0.416,67], d[0.651,0.365], g[1.064]
# >60, c[0.361,83], d[0.650,0.520], g[0.944]
# >61, c[0.362,83], d[0.558,0.536], g[0.923]
# >62, c[0.426,83], d[0.579,0.407], g[1.145]
# >63, c[0.251,83], d[0.527,0.355], g[1.097]
# >64, c[0.204,100], d[0.440,0.489], g[1.260]
# >65, c[0.336,67], d[0.599,0.406], g[1.012]
# >66, c[0.274,100], d[0.484,0.511], g[1.055]
# >67, c[0.360,83], d[0.494,0.455], g[1.012]
# >68, c[0.158,100], d[0.599,0.520], g[1.090]
# >69, c[0.047,100], d[0.643,0.527], g[1.076]
# >70, c[0.394,67], d[0.551,0.536], g[1.052]
# >71, c[0.187,100], d[0.444,0.417], g[1.051]
# >72, c[0.443,83], d[0.532,0.419], g[0.959]
# >73, c[0.286,100], d[0.484,0.464], g[0.900]
# >74, c[0.490,83], d[0.390,0.437], g[0.949]
# >75, c[0.380,100], d[0.650,0.673], g[0.933]
# >76, c[0.511,83], d[0.584,0.640], g[1.086]
# >77, c[0.289,100], d[0.777,0.641], g[0.780]
# >78, c[0.373,83], d[0.514,0.432], g[1.164]
# >79, c[0.234,100], d[0.769,0.414], g[0.839]
# >80, c[0.330,83], d[0.470,0.654], g[1.169]
# >81, c[0.296,83], d[0.686,0.391], g[1.115]
# >82, c[0.340,83], d[0.458,0.414], g[0.926]
# >83, c[0.522,67], d[0.529,0.469], g[1.096]
# >84, c[0.245,100], d[0.596,0.586], g[1.268]
# >85, c[0.432,83], d[0.595,0.654], g[1.008]
# >86, c[0.375,100], d[0.569,0.679], g[1.099]
# >87, c[0.334,83], d[0.732,0.547], g[1.102]
# 15/15 [==============================] - 0s 25ms/step - loss: 0.4534 - accuracy: 0.8000
# >1, c[0.405,83], d[0.714,0.518], g[1.250]
# >2, c[0.404,67], d[0.693,0.437], g[0.967]
# >3, c[0.142,100], d[0.634,0.385], g[1.287]
# >4, c[0.296,100], d[0.565,0.449], g[0.985]
# >5, c[0.131,100], d[0.411,0.458], g[1.304]
# >6, c[0.375,83], d[0.396,0.460], g[1.223]
# >7, c[0.434,83], d[0.716,0.375], g[0.746]
# >8, c[0.188,100], d[0.561,0.538], g[0.861]
# >9, c[0.423,67], d[0.455,0.520], g[1.198]
# >10, c[0.198,100], d[0.613,0.437], g[0.993]
# >11, c[0.352,83], d[0.439,0.561], g[1.278]
# >12, c[0.321,83], d[0.742,0.481], g[1.160]
# >13, c[0.329,83], d[0.397,0.485], g[1.072]
# >14, c[0.405,83], d[0.723,0.353], g[1.116]
# >15, c[0.372,67], d[0.763,0.464], g[1.081]
# >16, c[0.280,83], d[0.654,0.706], g[0.894]
# >17, c[0.220,83], d[0.967,0.531], g[0.946]
# >18, c[0.342,83], d[0.562,0.567], g[1.054]
# >19, c[0.426,67], d[0.628,0.672], g[0.993]
# >20, c[0.394,83], d[0.732,0.564], g[0.933]
# >21, c[0.289,83], d[0.632,0.574], g[0.995]
# >22, c[0.509,50], d[0.657,0.584], g[1.028]
# >23, c[0.430,67], d[0.818,0.538], g[1.065]
# >24, c[0.229,100], d[0.839,0.609], g[0.962]
# >25, c[0.303,100], d[0.618,0.572], g[0.841]
# >26, c[0.265,83], d[0.822,0.482], g[0.976]
# >27, c[0.327,83], d[0.767,0.591], g[0.822]
# >28, c[0.296,100], d[0.631,0.598], g[0.797]
# >29, c[0.280,100], d[0.804,0.572], g[0.807]
# >30, c[0.307,83], d[0.849,0.541], g[0.812]
# >31, c[0.307,100], d[0.596,0.619], g[0.639]
# >32, c[0.479,67], d[0.621,0.671], g[0.769]
# >33, c[0.460,67], d[0.675,0.571], g[0.750]
# >34, c[0.349,83], d[0.497,0.624], g[0.707]
# >35, c[0.329,83], d[0.688,0.808], g[1.064]
# >36, c[0.269,83], d[0.642,0.552], g[0.960]
# >37, c[0.244,100], d[0.545,0.558], g[0.819]
# >38, c[0.324,83], d[0.475,0.512], g[1.068]
# >39, c[0.322,100], d[0.711,0.589], g[0.830]
# >40, c[0.165,100], d[0.659,0.638], g[0.879]
# >41, c[0.454,67], d[0.611,0.580], g[0.901]
# >42, c[0.246,83], d[0.724,0.602], g[1.012]
# >43, c[0.322,83], d[0.593,0.552], g[0.915]
# >44, c[0.265,100], d[0.670,0.643], g[1.028]
# >45, c[0.450,67], d[0.482,0.579], g[1.005]
# >46, c[0.409,83], d[0.598,0.670], g[0.849]
# >47, c[0.316,83], d[0.699,0.597], g[1.041]
# >48, c[0.377,83], d[0.628,0.489], g[0.956]
# >49, c[0.268,83], d[0.742,0.541], g[0.985]
# >50, c[0.357,100], d[0.485,0.607], g[1.000]
# >51, c[0.346,83], d[0.472,0.554], g[0.844]
# >52, c[0.300,100], d[0.339,0.609], g[0.853]
# >53, c[0.353,67], d[0.365,0.606], g[0.806]
# >54, c[0.283,80], d[0.533,0.446], g[0.967]
# >55, c[0.271,83], d[0.664,0.523], g[1.020]
# >56, c[0.351,83], d[0.627,0.420], g[1.027]
# >57, c[0.386,83], d[0.793,0.542], g[0.949]
# >58, c[0.290,83], d[0.608,0.532], g[1.034]
# >59, c[0.311,83], d[0.716,0.500], g[0.904]
# >60, c[0.316,83], d[0.680,0.595], g[0.903]
# >61, c[0.428,67], d[0.753,0.607], g[0.806]
# >62, c[0.270,83], d[0.533,0.686], g[0.875]
# >63, c[0.382,67], d[0.472,0.839], g[0.821]
# >64, c[0.313,67], d[0.746,0.521], g[0.947]
# >65, c[0.442,83], d[0.876,0.766], g[0.764]
# >66, c[0.294,100], d[0.616,0.705], g[0.730]
# >67, c[0.190,100], d[0.491,0.634], g[0.826]
# >68, c[0.436,67], d[0.583,0.421], g[0.835]
# >69, c[0.461,83], d[0.542,0.838], g[0.907]
# >70, c[0.259,83], d[0.535,0.590], g[0.921]
# >71, c[0.251,100], d[0.576,0.481], g[0.983]
# >72, c[0.361,83], d[0.815,0.598], g[1.127]
# >73, c[0.371,67], d[0.695,0.696], g[1.136]
# >74, c[0.193,100], d[0.730,0.385], g[1.288]
# >75, c[0.300,100], d[0.786,0.435], g[0.839]
# >76, c[0.245,83], d[1.006,0.510], g[0.993]
# >77, c[0.294,83], d[0.606,0.487], g[0.991]
# >78, c[0.300,83], d[0.721,0.447], g[1.298]
# >79, c[0.381,83], d[0.642,0.446], g[0.796]
# >80, c[0.428,83], d[0.555,0.493], g[0.999]
# >81, c[0.287,83], d[0.764,0.619], g[1.024]
# >82, c[0.287,83], d[0.699,0.609], g[1.022]
# >83, c[0.478,50], d[0.472,0.509], g[0.926]
# >84, c[0.276,83], d[0.659,0.582], g[0.926]
# >85, c[0.301,83], d[0.494,0.566], g[1.050]
# >86, c[0.664,67], d[0.584,0.549], g[1.080]
# >87, c[0.249,100], d[0.779,0.499], g[1.155]
# 15/15 [==============================] - 0s 25ms/step - loss: 0.5938 - accuracy: 0.7333
# >1, c[0.561,75], d[0.792,0.419], g[1.150]
# >2, c[0.172,100], d[0.751,0.478], g[0.976]
# >3, c[0.561,50], d[0.736,0.508], g[0.976]
# >4, c[0.337,83], d[0.680,0.578], g[0.978]
# >5, c[0.316,83], d[0.773,0.525], g[1.140]
# >6, c[0.315,100], d[0.781,0.579], g[0.881]
# >7, c[0.119,100], d[0.533,0.541], g[1.082]
# >8, c[0.229,100], d[0.723,0.480], g[0.899]
# >9, c[0.233,100], d[0.912,0.742], g[0.941]
# >10, c[0.229,83], d[0.631,0.520], g[0.910]
# >11, c[0.277,100], d[0.620,0.462], g[0.926]
# >12, c[0.308,83], d[0.738,0.493], g[0.985]
# >13, c[0.201,100], d[0.747,0.453], g[0.948]
# >14, c[0.273,100], d[0.740,0.555], g[0.860]
# >15, c[0.420,83], d[0.598,0.423], g[0.981]
# >16, c[0.164,100], d[0.594,0.607], g[1.017]
# >17, c[0.217,100], d[0.729,0.497], g[1.040]
# >18, c[0.464,67], d[0.772,0.547], g[1.058]
# >19, c[0.248,100], d[0.615,0.632], g[0.917]
# >20, c[0.272,100], d[0.675,0.573], g[0.987]
# >21, c[0.497,67], d[0.754,0.413], g[1.040]
# >22, c[0.227,83], d[0.639,0.419], g[1.112]
# >23, c[0.263,100], d[0.794,0.598], g[1.096]
# >24, c[0.528,67], d[0.674,0.552], g[0.960]
# >25, c[0.360,83], d[0.605,0.628], g[1.119]
# >26, c[0.482,83], d[0.746,0.460], g[0.898]
# >27, c[0.389,83], d[0.730,0.627], g[1.040]
# >28, c[0.318,100], d[0.785,0.507], g[1.110]
# >29, c[0.303,83], d[0.786,0.481], g[0.746]
# >30, c[0.302,100], d[0.580,0.585], g[0.947]
# >31, c[0.298,100], d[0.578,0.799], g[0.823]
# >32, c[0.383,83], d[0.581,0.535], g[0.881]
# >33, c[0.203,100], d[0.680,0.586], g[0.761]
# >34, c[0.145,100], d[0.663,0.607], g[0.923]
# >35, c[0.345,100], d[0.687,0.570], g[0.985]
# >36, c[0.366,67], d[0.598,0.634], g[1.090]
# >37, c[0.508,67], d[0.388,0.554], g[0.998]
# >38, c[0.441,67], d[0.771,0.493], g[1.087]
# >39, c[0.416,67], d[0.617,0.506], g[1.194]
# >40, c[0.497,50], d[0.698,0.649], g[0.881]
# >41, c[0.196,100], d[0.586,0.353], g[1.120]
# >42, c[0.362,83], d[0.588,0.463], g[1.000]
# >43, c[0.343,83], d[0.689,0.501], g[1.026]
# >44, c[0.316,100], d[0.601,0.590], g[0.856]
# >45, c[0.235,100], d[0.553,0.551], g[0.898]
# >46, c[0.378,83], d[0.796,0.599], g[0.889]
# >47, c[0.393,83], d[0.584,0.631], g[1.074]
# >48, c[0.529,67], d[0.614,0.508], g[0.856]
# >49, c[0.237,100], d[0.682,0.543], g[0.926]
# >50, c[0.229,83], d[0.667,0.473], g[0.932]
# >51, c[0.399,83], d[0.516,0.559], g[0.960]
# >52, c[0.211,100], d[0.511,0.557], g[1.073]
# >53, c[0.246,100], d[0.550,0.448], g[1.236]
# >54, c[0.243,83], d[0.571,0.482], g[1.103]
# >55, c[0.447,67], d[0.586,0.414], g[1.023]
# >56, c[0.293,83], d[0.728,0.538], g[1.191]
# >57, c[0.226,100], d[0.585,0.474], g[1.033]
# >58, c[0.174,100], d[0.508,0.461], g[0.968]
# >59, c[0.370,100], d[0.627,0.463], g[1.126]
# >60, c[0.362,83], d[0.573,0.549], g[0.987]
# >61, c[0.400,67], d[0.770,0.631], g[0.908]
# >62, c[0.277,83], d[0.718,0.466], g[0.887]
# >63, c[0.499,83], d[0.544,0.672], g[0.880]
# >64, c[0.343,100], d[0.753,0.483], g[1.086]
# >65, c[0.236,100], d[0.410,0.561], g[1.004]
# >66, c[0.265,83], d[0.613,0.468], g[1.308]
# >67, c[0.333,100], d[0.758,0.445], g[0.993]
# >68, c[0.406,67], d[0.563,0.422], g[1.136]
# >69, c[0.232,100], d[0.594,0.690], g[1.089]
# >70, c[0.302,83], d[0.607,0.399], g[1.262]
# >71, c[0.231,100], d[0.557,0.457], g[0.964]
# >72, c[0.320,100], d[0.559,0.368], g[0.966]
# >73, c[0.234,83], d[0.596,0.565], g[0.985]
# >74, c[0.352,83], d[0.601,0.540], g[1.115]
# >75, c[0.316,100], d[0.511,0.567], g[1.127]
# >76, c[0.297,83], d[0.525,0.506], g[0.859]
# >77, c[0.198,100], d[0.534,0.451], g[1.020]
# >78, c[0.439,67], d[0.566,0.458], g[0.966]
# >79, c[0.328,83], d[0.705,0.478], g[0.940]
# >80, c[0.307,100], d[0.697,0.598], g[1.127]
# >81, c[0.319,83], d[0.855,0.533], g[0.906]
# >82, c[0.412,83], d[0.658,0.528], g[1.239]
# >83, c[0.426,83], d[0.644,0.475], g[1.104]
# >84, c[0.331,83], d[0.831,0.424], g[1.066]
# >85, c[0.351,67], d[0.587,0.584], g[0.874]
# >86, c[0.316,83], d[0.560,0.521], g[0.992]
# >87, c[0.304,100], d[0.666,0.508], g[0.915]
# 15/15 [==============================] - 0s 24ms/step - loss: 0.6337 - accuracy: 0.7000
# >1, c[0.593,72], d[0.710,0.397], g[1.191]
# >2, c[0.306,83], d[0.494,0.499], g[0.883]
# >3, c[0.299,100], d[0.560,0.506], g[1.212]
# >4, c[0.289,83], d[0.445,0.535], g[1.023]
# >5, c[0.339,83], d[0.561,0.385], g[1.274]
# >6, c[0.299,83], d[0.680,0.471], g[1.206]
# >7, c[0.317,100], d[0.653,0.513], g[1.186]
# >8, c[0.377,83], d[0.615,0.395], g[1.065]
# >9, c[0.426,83], d[0.647,0.370], g[1.176]
# >10, c[0.160,100], d[0.635,0.316], g[1.228]
# >11, c[0.421,67], d[0.718,0.505], g[1.020]
# >12, c[0.473,83], d[0.606,0.559], g[1.049]
# >13, c[0.259,100], d[0.637,0.474], g[1.194]
# >14, c[0.258,100], d[0.660,0.444], g[0.887]
# >15, c[0.131,100], d[0.385,0.433], g[0.916]
# >16, c[0.356,67], d[0.656,0.700], g[1.118]
# >17, c[0.456,67], d[0.627,0.533], g[0.944]
# >18, c[0.347,100], d[0.513,0.518], g[0.955]
# >19, c[0.360,83], d[0.783,0.449], g[1.098]
# >20, c[0.237,100], d[0.595,0.476], g[0.950]
# >21, c[0.447,83], d[0.693,0.366], g[1.046]
# >22, c[0.188,100], d[0.513,0.480], g[0.781]
# >23, c[0.239,100], d[0.531,0.632], g[0.837]
# >24, c[0.720,50], d[0.701,0.447], g[0.926]
# >25, c[0.253,100], d[0.490,0.397], g[1.000]
# >26, c[0.366,83], d[0.467,0.476], g[1.047]
# >27, c[0.360,80], d[0.502,0.536], g[0.931]
# >28, c[0.273,100], d[0.502,0.477], g[1.035]
# >29, c[0.374,67], d[0.594,0.487], g[1.191]
# >30, c[0.273,100], d[0.667,0.502], g[1.041]
# >31, c[0.292,100], d[0.675,0.551], g[0.920]
# >32, c[0.292,100], d[0.417,0.667], g[1.133]
# >33, c[0.669,50], d[0.755,0.565], g[1.149]
# >34, c[0.379,83], d[0.663,0.529], g[1.225]
# >35, c[0.396,67], d[0.503,0.448], g[1.048]
# >36, c[0.240,83], d[0.549,0.458], g[1.021]
# >37, c[0.404,83], d[0.601,0.505], g[1.078]
# >38, c[0.313,67], d[0.861,0.405], g[0.952]
# >39, c[0.298,100], d[0.500,0.424], g[1.091]
# >40, c[0.244,100], d[0.720,0.453], g[0.906]
# >41, c[0.197,100], d[0.624,0.474], g[1.023]
# >42, c[0.321,100], d[0.587,0.556], g[1.089]
# >43, c[0.405,83], d[0.492,0.448], g[0.894]
# >44, c[0.318,100], d[0.577,0.532], g[1.178]
# >45, c[0.319,83], d[0.654,0.463], g[0.918]
# >46, c[0.455,67], d[0.645,0.414], g[0.879]
# >47, c[0.235,100], d[0.499,0.445], g[1.011]
# >48, c[0.480,67], d[0.582,0.545], g[1.005]
# >49, c[0.294,100], d[0.606,0.549], g[1.006]
# >50, c[0.314,83], d[0.464,0.464], g[1.101]
# >51, c[0.310,83], d[0.420,0.452], g[0.974]
# >52, c[0.415,83], d[0.402,0.551], g[1.060]
# >53, c[0.226,100], d[0.512,0.498], g[1.083]
# >54, c[0.196,100], d[0.659,0.414], g[1.024]
# >55, c[0.318,83], d[0.509,0.453], g[0.911]
# >56, c[0.230,100], d[0.577,0.453], g[1.017]
# >57, c[0.240,100], d[0.657,0.449], g[1.069]
# >58, c[0.254,100], d[0.407,0.400], g[1.187]
# >59, c[0.400,83], d[0.391,0.504], g[0.903]
# >60, c[0.159,100], d[0.712,0.441], g[1.113]
# >61, c[0.244,100], d[0.416,0.457], g[1.061]
# >62, c[0.319,100], d[0.323,0.530], g[1.109]
# >63, c[0.396,67], d[0.640,0.481], g[0.957]
# >64, c[0.482,67], d[0.514,0.580], g[1.003]
# >65, c[0.329,83], d[0.558,0.649], g[1.214]
# >66, c[0.440,67], d[0.546,0.838], g[1.121]
# >67, c[0.291,100], d[0.646,0.489], g[0.926]
# >68, c[0.357,83], d[0.682,0.676], g[1.116]
# >69, c[0.357,67], d[0.662,0.626], g[1.255]
# >70, c[0.444,67], d[0.656,0.488], g[1.156]
# >71, c[0.345,83], d[0.508,0.522], g[1.342]
# >72, c[0.319,100], d[0.572,0.405], g[1.125]
# >73, c[0.290,100], d[0.683,0.407], g[1.207]
# >74, c[0.489,67], d[0.795,0.363], g[1.156]
# >75, c[0.402,83], d[0.609,0.474], g[1.021]
# >76, c[0.338,80], d[0.466,0.613], g[1.226]
# >77, c[0.273,100], d[0.847,0.415], g[0.860]
# >78, c[0.248,100], d[0.720,0.657], g[1.151]
# >79, c[0.459,83], d[0.589,0.381], g[0.711]
# >80, c[0.123,100], d[0.477,0.651], g[1.005]
# >81, c[0.258,100], d[0.621,0.691], g[1.042]
# >82, c[0.287,83], d[0.633,0.446], g[1.141]
# >83, c[0.322,83], d[0.677,0.547], g[1.163]
# >84, c[0.239,83], d[0.625,0.389], g[1.084]
# >85, c[0.240,83], d[0.441,0.368], g[0.884]
# >86, c[0.299,100], d[0.600,0.534], g[1.162]
# >87, c[0.386,83], d[0.681,0.450], g[1.044]
# 15/15 [==============================] - 0s 22ms/step - loss: 0.4836 - accuracy: 0.7333
# >1, c[0.460,78], d[0.676,0.489], g[0.989]
# >2, c[0.328,83], d[0.423,0.448], g[0.960]
# >3, c[0.459,67], d[0.435,0.721], g[1.017]
# >4, c[0.365,67], d[0.604,0.444], g[0.995]
# >5, c[0.246,83], d[0.521,0.429], g[1.016]
# >6, c[0.263,83], d[0.580,0.538], g[0.950]
# >7, c[0.422,83], d[0.435,0.548], g[0.940]
# >8, c[0.282,100], d[0.587,0.746], g[0.914]
# >9, c[0.193,100], d[0.729,0.484], g[0.945]
# >10, c[0.340,83], d[0.517,0.498], g[1.144]
# >11, c[0.326,83], d[0.520,0.509], g[1.026]
# >12, c[0.348,83], d[0.757,0.385], g[1.148]
# >13, c[0.477,67], d[0.537,0.451], g[1.014]
# >14, c[0.295,100], d[0.746,0.359], g[1.152]
# >15, c[0.410,67], d[0.625,0.459], g[1.054]
# >16, c[0.276,83], d[0.515,0.428], g[1.117]
# >17, c[0.196,100], d[0.631,0.486], g[0.897]
# >18, c[0.212,100], d[0.589,0.571], g[0.938]
# >19, c[0.630,83], d[0.519,0.460], g[1.039]
# >20, c[0.182,100], d[0.469,0.585], g[0.993]
# >21, c[0.376,67], d[0.753,0.471], g[0.981]
# >22, c[0.189,100], d[0.526,0.680], g[0.780]
# >23, c[0.434,67], d[0.441,0.549], g[0.916]
# >24, c[0.234,100], d[0.464,0.579], g[0.917]
# >25, c[0.348,100], d[0.460,0.572], g[0.992]
# >26, c[0.522,50], d[0.601,0.520], g[0.939]
# >27, c[0.459,50], d[0.682,0.552], g[0.855]
# >28, c[0.251,83], d[0.748,0.506], g[1.048]
# >29, c[0.276,100], d[0.599,0.454], g[0.904]
# >30, c[0.331,83], d[0.644,0.470], g[0.737]
# >31, c[0.272,100], d[0.608,0.542], g[0.955]
# >32, c[0.350,83], d[0.647,0.633], g[0.954]
# >33, c[0.238,100], d[0.449,0.504], g[1.018]
# >34, c[0.272,100], d[0.471,0.565], g[0.969]
# >35, c[0.303,100], d[0.702,0.626], g[0.856]
# >36, c[0.315,100], d[0.597,0.441], g[0.936]
# >37, c[0.271,100], d[0.795,0.799], g[1.042]
# >38, c[0.304,100], d[0.450,0.569], g[1.288]
# >39, c[0.237,100], d[0.798,0.696], g[1.136]
# >40, c[0.318,83], d[0.722,0.421], g[0.826]
# >41, c[0.344,67], d[0.532,0.528], g[0.958]
# >42, c[0.233,100], d[0.666,0.455], g[0.825]
# >43, c[0.219,100], d[0.594,0.673], g[0.766]
# >44, c[0.264,100], d[0.653,0.615], g[0.762]
# >45, c[0.411,67], d[0.663,0.740], g[0.938]
# >46, c[0.411,67], d[0.575,0.555], g[1.068]
# >47, c[0.245,100], d[0.716,0.493], g[1.005]
# >48, c[0.208,100], d[0.642,0.565], g[1.057]
# >49, c[0.415,83], d[0.577,0.439], g[0.976]
# >50, c[0.397,83], d[0.675,0.565], g[1.034]
# >51, c[0.188,100], d[0.564,0.414], g[1.119]
# >52, c[0.130,100], d[0.585,0.334], g[1.058]
# >53, c[0.287,83], d[0.480,0.469], g[1.081]
# >54, c[0.177,100], d[0.603,0.400], g[1.157]
# >55, c[0.306,83], d[0.482,0.476], g[0.908]
# ...
# >77, c[0.311,83], d[0.619,0.567], g[1.214]
# >78, c[0.331,83], d[1.246,0.344], g[1.272]
# >79, c[0.245,100], d[0.455,0.472], g[1.214]
# >80, c[0.399,83], d[0.488,0.461], g[0.914]
# >81, c[0.246,100], d[0.735,0.345], g[0.844]
# >82, c[0.334,100], d[0.618,0.518], g[1.142]
# >83, c[0.277,83], d[0.812,0.362], g[1.266]
# >84, c[0.327,100], d[0.702,0.527], g[1.029]
# >85, c[0.198,100], d[0.827,0.444], g[1.041]
# >86, c[0.225,100], d[0.599,0.334], g[1.309]
# >87, c[0.518,67], d[0.918,0.479], g[1.329]
# 15/15 [==============================] - 0s 22ms/step - loss: 0.8483 - accuracy: 0.6667
# >1, c[0.742,69], d[0.262,0.439], g[1.147]
# >2, c[0.220,100], d[0.634,0.450], g[1.043]
# >3, c[0.372,67], d[0.535,0.442], g[1.178]
# >4, c[0.256,100], d[0.798,0.468], g[1.143]
# >5, c[0.483,50], d[0.489,0.617], g[0.883]
# >6, c[0.263,83], d[0.511,0.422], g[1.511]
# >7, c[0.385,83], d[0.517,0.406], g[1.255]
# >8, c[0.414,83], d[0.448,0.381], g[1.188]
# >9, c[0.316,100], d[0.768,0.402], g[1.158]
# >10, c[0.543,50], d[0.609,0.436], g[1.033]
# >11, c[0.344,83], d[0.477,0.524], g[1.175]
# >12, c[0.380,83], d[0.682,0.558], g[1.158]
# >13, c[0.270,100], d[0.634,0.529], g[1.307]
# >14, c[0.377,83], d[0.673,0.403], g[1.384]
# >15, c[0.313,100], d[0.554,0.427], g[1.132]
# >16, c[0.326,83], d[0.601,0.462], g[1.014]
# >17, c[0.176,100], d[0.575,0.504], g[0.900]
# >18, c[0.202,100], d[1.102,0.605], g[1.243]
# >19, c[0.235,83], d[0.849,0.303], g[0.838]
# >20, c[0.337,83], d[0.408,0.558], g[1.392]
# >21, c[0.345,83], d[0.836,0.535], g[1.277]
# >22, c[0.332,100], d[0.707,0.689], g[1.019]
# >23, c[0.242,100], d[0.380,0.591], g[1.033]
# >24, c[0.174,100], d[0.755,0.418], g[1.215]
# >25, c[0.192,100], d[0.743,0.431], g[1.124]
# >26, c[0.516,67], d[0.589,0.476], g[1.528]
# >27, c[0.410,67], d[0.685,0.352], g[1.169]
# >28, c[0.318,83], d[0.558,0.403], g[0.847]
# >29, c[0.311,83], d[0.649,0.681], g[1.061]
# >30, c[0.175,100], d[0.674,0.537], g[1.367]
# >31, c[0.282,100], d[0.782,0.555], g[1.342]
# >32, c[0.203,100], d[0.822,0.388], g[1.136]
# >33, c[0.386,67], d[0.757,0.467], g[0.917]
# >34, c[0.200,100], d[0.508,0.422], g[1.132]
# >35, c[0.393,83], d[0.986,0.603], g[0.971]
# >36, c[0.457,83], d[0.878,0.624], g[1.104]
# >37, c[0.449,67], d[0.744,0.473], g[1.028]
# >38, c[0.282,100], d[0.526,0.675], g[1.185]
# >39, c[0.412,67], d[0.855,0.494], g[1.325]
# >40, c[0.401,83], d[0.839,0.434], g[1.041]
# >41, c[0.140,100], d[0.621,0.537], g[1.169]
# >42, c[0.306,83], d[0.707,0.433], g[1.124]
# >43, c[0.274,83], d[0.456,0.720], g[1.181]
# >44, c[0.302,83], d[1.048,0.400], g[1.222]
# >45, c[0.506,50], d[0.590,0.457], g[1.097]
# >46, c[0.261,100], d[0.680,0.589], g[0.829]
# >47, c[0.246,100], d[0.632,0.488], g[1.230]
# >48, c[0.262,100], d[0.399,0.497], g[1.145]
# >49, c[0.190,100], d[0.464,0.477], g[1.004]
# >50, c[0.214,100], d[0.392,0.548], g[1.032]
# >51, c[0.332,83], d[0.413,0.554], g[1.101]
# >52, c[0.276,83], d[0.380,0.497], g[1.111]
# >53, c[0.338,83], d[0.466,0.441], g[1.084]
# >54, c[0.173,100], d[0.517,0.515], g[1.256]
# >55, c[0.189,100], d[0.772,0.564], g[1.136]
# >56, c[0.548,67], d[0.735,0.453], g[1.194]
# >57, c[0.345,83], d[0.655,0.510], g[0.835]
# >58, c[0.384,83], d[0.578,0.622], g[0.852]
# >59, c[0.362,83], d[0.601,0.515], g[0.744]
# >60, c[0.470,83], d[0.586,0.622], g[1.128]
# >61, c[0.323,83], d[0.595,0.607], g[0.703]
# >62, c[0.359,83], d[0.560,0.743], g[1.061]
# >63, c[0.271,100], d[0.477,0.541], g[1.150]
# >64, c[0.245,100], d[0.323,0.421], g[1.066]
# >65, c[0.605,50], d[0.537,0.471], g[1.179]
# >66, c[0.221,100], d[0.579,0.435], g[1.223]
# >67, c[0.508,83], d[0.535,0.378], g[0.956]
# >68, c[0.420,83], d[0.561,0.448], g[1.027]
# >69, c[0.319,83], d[0.520,0.478], g[1.015]
# >70, c[0.421,83], d[0.438,0.621], g[1.080]
# >71, c[0.466,67], d[0.578,0.473], g[1.641]
# >72, c[0.504,67], d[0.408,0.444], g[1.361]
# >73, c[0.249,83], d[0.329,0.381], g[1.355]
# >74, c[0.213,100], d[0.580,0.372], g[1.238]
# >75, c[0.349,100], d[0.608,0.331], g[1.317]
# >76, c[0.363,83], d[0.621,0.391], g[1.177]
# >77, c[0.282,100], d[0.631,0.481], g[1.061]
# >78, c[0.277,83], d[0.461,0.499], g[1.043]
# >79, c[0.208,100], d[0.570,0.582], g[1.154]
# >80, c[0.285,83], d[0.233,0.447], g[0.861]
# >81, c[0.249,100], d[0.421,0.510], g[1.079]
# >82, c[0.131,100], d[0.281,0.361], g[1.032]
# >83, c[0.360,83], d[0.605,0.442], g[1.040]
# >84, c[0.330,100], d[0.506,0.647], g[1.030]
# >85, c[0.275,83], d[0.737,0.538], g[1.109]
# >86, c[0.420,83], d[0.713,0.601], g[1.250]
# >87, c[0.142,100], d[0.587,0.531], g[1.134]
# 15/15 [==============================] - 0s 22ms/step - loss: 1.0233 - accuracy: 0.6667
# >1, c[0.895,69], d[0.503,0.443], g[0.948]
# >2, c[0.411,83], d[0.447,0.387], g[1.106]
# >3, c[0.356,83], d[0.373,0.484], g[0.955]
# >4, c[0.266,83], d[0.425,0.583], g[1.281]
# >5, c[0.234,83], d[0.195,0.591], g[1.168]
# >6, c[0.297,83], d[0.637,0.459], g[0.978]
# >7, c[0.426,67], d[0.541,0.395], g[1.266]
# >8, c[0.289,83], d[0.615,0.489], g[1.165]
# >9, c[0.154,100], d[0.769,0.399], g[0.977]
# >10, c[0.247,100], d[0.580,0.450], g[1.005]
# >11, c[0.298,83], d[0.557,0.547], g[0.908]
# >12, c[0.227,83], d[0.595,0.541], g[1.204]
# >13, c[0.321,83], d[0.643,0.442], g[1.079]
# >14, c[0.403,67], d[0.308,0.552], g[1.246]
# >15, c[0.175,100], d[0.526,0.563], g[1.099]
# >16, c[0.639,50], d[0.520,0.457], g[1.198]
# >17, c[0.341,83], d[0.634,0.444], g[1.061]
# >18, c[0.438,83], d[0.280,0.425], g[1.194]
# >19, c[0.273,100], d[0.716,0.560], g[1.149]
# >20, c[0.418,67], d[0.506,0.390], g[0.971]
# >21, c[0.346,83], d[0.429,0.401], g[1.154]
# >22, c[0.348,67], d[0.581,0.473], g[1.219]
# >23, c[0.437,67], d[0.698,0.518], g[1.267]
# >24, c[0.326,100], d[0.339,0.567], g[1.124]
# >25, c[0.247,83], d[0.443,0.442], g[1.311]
# >26, c[0.468,67], d[0.660,0.367], g[1.341]
# >27, c[0.275,100], d[0.391,0.580], g[1.210]
# >28, c[0.328,83], d[0.246,0.420], g[1.119]
# >29, c[0.251,100], d[0.463,0.410], g[1.240]
# >30, c[0.238,100], d[0.576,0.355], g[1.262]
# >31, c[0.357,83], d[0.307,0.410], g[1.200]
# >32, c[0.256,100], d[0.734,0.453], g[0.924]
# >33, c[0.532,67], d[0.412,0.594], g[1.080]
# >34, c[0.287,83], d[0.257,0.427], g[0.964]
# >35, c[0.145,100], d[0.775,0.499], g[1.100]
# >36, c[0.537,67], d[0.425,0.509], g[1.293]
# >37, c[0.212,83], d[0.673,0.499], g[1.341]
# >38, c[0.251,100], d[0.642,0.418], g[1.491]
# >39, c[0.356,83], d[0.912,0.565], g[1.011]
# >40, c[0.406,83], d[0.328,0.417], g[1.434]
# >41, c[0.433,83], d[0.949,0.511], g[1.047]
# >42, c[0.153,100], d[0.314,0.298], g[1.052]
# >43, c[0.302,83], d[0.161,0.323], g[1.197]
# >44, c[0.288,83], d[0.521,0.456], g[1.068]
# >45, c[0.288,100], d[0.770,0.412], g[1.335]
# >46, c[0.241,100], d[0.210,0.422], g[1.099]
# >47, c[0.353,83], d[0.329,0.447], g[1.400]
# >48, c[0.379,83], d[0.401,0.303], g[1.515]
# >49, c[0.173,100], d[0.408,0.289], g[1.310]
# >50, c[0.422,83], d[0.611,0.358], g[1.368]
# >51, c[0.225,100], d[0.677,0.309], g[1.482]
# >52, c[0.192,100], d[0.596,0.360], g[1.263]
# >53, c[0.252,83], d[0.295,0.318], g[1.245]
# >54, c[0.268,83], d[0.746,0.500], g[1.408]
# >55, c[0.255,83], d[0.441,0.402], g[1.238]
# >56, c[0.326,100], d[0.589,0.343], g[1.109]
# >57, c[0.376,100], d[0.592,0.483], g[1.085]
# >58, c[0.292,83], d[0.431,0.391], g[1.220]
# >59, c[0.218,100], d[0.414,0.487], g[1.370]
# >60, c[0.350,83], d[0.694,0.319], g[1.517]
# >61, c[0.249,83], d[0.404,0.338], g[0.958]
# >62, c[0.507,67], d[0.529,0.428], g[1.391]
# >63, c[0.198,100], d[0.498,0.456], g[1.560]
# >64, c[0.629,67], d[0.493,0.514], g[0.987]
# >65, c[0.331,83], d[0.277,0.397], g[1.466]
# >66, c[0.315,83], d[0.536,0.454], g[1.414]
# >67, c[0.319,83], d[0.544,0.469], g[1.195]
# >68, c[0.354,83], d[0.675,0.464], g[1.212]
# >69, c[0.233,100], d[0.763,0.405], g[1.309]
# >70, c[0.332,83], d[0.680,0.390], g[1.228]
# >71, c[0.253,100], d[0.492,0.437], g[1.434]
# >72, c[0.331,100], d[0.802,0.421], g[1.277]
# >73, c[0.293,83], d[0.864,0.536], g[1.073]
# >74, c[0.587,67], d[0.618,0.684], g[0.937]
# >75, c[0.398,67], d[0.312,1.120], g[1.439]
# >76, c[0.422,67], d[0.489,0.389], g[1.394]
# >77, c[0.187,100], d[0.735,0.199], g[2.361]
# >78, c[0.224,100], d[0.381,0.192], g[1.188]
# >79, c[0.455,67], d[0.298,0.330], g[1.076]
# >80, c[0.486,67], d[0.582,0.332], g[0.969]
# >81, c[0.252,100], d[0.346,0.406], g[0.862]
# >82, c[0.109,100], d[0.286,0.390], g[1.240]
# >83, c[0.576,67], d[0.819,0.430], g[1.160]
# >84, c[0.597,50], d[0.337,0.400], g[1.101]
# >85, c[0.355,67], d[0.355,0.587], g[1.178]
# >86, c[0.305,83], d[0.701,0.363], g[1.626]
# >87, c[0.220,100], d[0.672,0.414], g[1.174]
# 15/15 [==============================] - 0s 23ms/step - loss: 1.0287 - accuracy: 0.6667
# >1, c[0.915,69], d[0.433,0.518], g[1.589]
# >2, c[0.417,67], d[0.406,0.427], g[1.617]
# >3, c[0.306,83], d[0.586,0.374], g[0.990]
# >4, c[0.180,100], d[0.621,0.347], g[1.332]
# >5, c[0.459,67], d[0.714,0.314], g[1.264]
# >6, c[0.239,100], d[0.510,0.341], g[1.161]
# >7, c[0.348,83], d[0.477,0.412], g[1.337]
# >8, c[0.134,100], d[0.161,0.590], g[1.229]
# >9, c[0.158,100], d[0.257,0.497], g[1.415]
# >10, c[0.345,67], d[0.658,0.407], g[1.054]
# >11, c[0.456,67], d[0.520,0.461], g[1.073]
# >12, c[0.313,83], d[0.668,0.399], g[1.553]
# >13, c[0.183,100], d[0.259,0.714], g[1.248]
# >14, c[0.211,100], d[0.572,0.338], g[1.361]
# >15, c[0.222,100], d[0.478,0.320], g[1.300]
# >16, c[0.203,83], d[0.086,0.277], g[1.330]
# >17, c[0.437,83], d[0.192,0.363], g[1.636]
# >18, c[0.262,100], d[0.256,0.288], g[1.630]
# >19, c[0.169,100], d[0.461,0.294], g[1.783]
# >20, c[0.217,100], d[0.244,0.424], g[1.692]
# >21, c[0.145,100], d[0.535,0.295], g[1.327]
# >22, c[0.399,83], d[0.476,0.349], g[1.507]
# >23, c[0.222,100], d[0.772,0.272], g[1.214]
# >24, c[0.491,67], d[0.288,0.339], g[1.380]
# >25, c[0.128,100], d[0.470,0.371], g[1.542]
# >26, c[0.166,100], d[0.521,0.474], g[1.310]
# >27, c[0.412,83], d[0.687,0.284], g[1.596]
# >28, c[0.320,83], d[0.424,0.318], g[0.915]
# >29, c[0.181,100], d[0.745,0.408], g[1.282]
# >30, c[0.259,83], d[0.501,0.429], g[1.051]
# >31, c[0.243,83], d[0.318,0.370], g[1.303]
# >32, c[0.217,83], d[0.428,0.345], g[1.478]
# >33, c[0.301,83], d[0.506,0.378], g[1.257]
# >34, c[0.249,100], d[0.669,0.494], g[1.112]
# >35, c[0.267,83], d[0.420,0.297], g[1.219]
# >36, c[0.339,83], d[0.378,0.310], g[1.447]
# >37, c[0.421,67], d[0.663,0.367], g[1.013]
# >38, c[0.280,100], d[0.588,0.503], g[1.255]
# >39, c[0.298,100], d[0.447,0.466], g[1.192]
# >40, c[0.268,100], d[0.392,0.436], g[1.584]
# >41, c[0.301,83], d[0.334,0.284], g[1.112]
# >42, c[0.108,100], d[0.355,0.262], g[1.067]
# >43, c[0.303,83], d[0.639,0.342], g[1.574]
# >44, c[0.159,100], d[0.338,0.317], g[1.375]
# >45, c[0.267,100], d[0.467,0.370], g[1.452]
# >46, c[0.255,83], d[0.700,0.362], g[1.344]
# >47, c[0.244,83], d[0.398,0.312], g[1.387]
# >48, c[0.410,67], d[0.706,0.325], g[1.185]
# >49, c[0.526,67], d[0.498,0.357], g[1.316]
# >50, c[0.503,67], d[0.163,0.576], g[1.391]
# >51, c[0.255,83], d[0.606,0.304], g[1.427]
# >52, c[0.271,100], d[0.242,0.415], g[1.377]
# >53, c[0.204,100], d[0.480,0.232], g[1.810]
# >54, c[0.337,83], d[0.217,0.531], g[1.466]
# >55, c[0.343,83], d[0.612,0.217], g[1.816]
# >56, c[0.192,100], d[0.470,0.306], g[1.724]
# >57, c[0.377,67], d[0.577,0.206], g[1.528]
# >58, c[0.328,83], d[0.457,0.309], g[1.338]
# >59, c[0.430,83], d[0.300,0.283], g[1.328]
# >60, c[0.192,100], d[0.481,0.335], g[1.117]
# >61, c[0.373,83], d[0.302,0.305], g[1.238]
# >62, c[0.397,83], d[0.807,0.357], g[1.586]
# >63, c[0.264,83], d[0.284,0.307], g[1.324]
# >64, c[0.379,67], d[0.417,0.282], g[1.514]
# >65, c[0.261,100], d[0.701,0.613], g[1.103]
# >66, c[0.113,100], d[0.541,0.587], g[1.027]
# >67, c[0.214,100], d[0.567,1.368], g[1.178]
# >68, c[0.506,67], d[0.929,0.394], g[1.229]
# >69, c[0.345,67], d[0.590,0.443], g[0.638]
# >70, c[0.179,100], d[0.534,0.420], g[1.042]
# >71, c[0.264,100], d[0.806,0.815], g[1.784]
# >72, c[0.372,67], d[0.597,0.443], g[1.415]
# >73, c[0.429,67], d[1.046,0.313], g[1.449]
# >74, c[0.340,67], d[0.739,0.525], g[1.128]
# >75, c[0.190,83], d[1.056,0.249], g[1.440]
# >76, c[0.407,83], d[0.898,0.466], g[1.845]
# >77, c[0.366,83], d[0.844,0.311], g[1.207]
# >78, c[0.185,100], d[0.312,0.235], g[1.317]
# >79, c[0.341,83], d[0.438,0.500], g[1.333]
# >80, c[0.256,83], d[0.542,0.400], g[1.544]
# >81, c[0.223,100], d[0.540,0.480], g[1.237]
# >82, c[0.388,83], d[0.580,0.442], g[1.085]
# >83, c[0.331,83], d[0.304,0.456], g[1.526]
# >84, c[0.316,83], d[0.842,0.441], g[1.421]
# >85, c[0.227,100], d[0.484,0.509], g[1.348]
# >86, c[0.294,83], d[0.714,0.469], g[1.173]
# >87, c[0.385,67], d[0.396,0.551], g[1.327]
# 15/15 [==============================] - 0s 22ms/step - loss: 0.6764 - accuracy: 0.6667
# >1, c[0.605,69], d[0.605,0.474], g[1.445]
# >2, c[0.244,100], d[0.979,0.351], g[1.391]
# >3, c[0.238,100], d[0.558,0.334], g[1.350]
# >4, c[0.326,67], d[0.580,0.505], g[1.083]
# >5, c[0.393,83], d[0.817,0.602], g[1.301]
# >6, c[0.452,83], d[0.598,0.526], g[0.992]
# >7, c[0.213,100], d[0.782,0.665], g[1.732]
# >8, c[0.357,67], d[0.837,0.713], g[1.599]
# >9, c[0.162,100], d[1.042,0.323], g[1.498]
# >10, c[0.249,100], d[1.076,0.331], g[1.415]
# >11, c[0.318,83], d[0.969,0.452], g[1.390]
# >12, c[0.283,83], d[0.672,0.446], g[1.054]
# >13, c[0.168,100], d[0.771,0.356], g[1.207]
# >14, c[0.249,100], d[0.820,0.490], g[1.159]
# >15, c[0.395,83], d[0.569,0.536], g[1.531]
# >16, c[0.181,100], d[0.526,0.322], g[1.461]
# >17, c[0.551,67], d[0.591,0.374], g[1.797]
# >18, c[0.176,100], d[0.845,0.442], g[1.557]
# >19, c[0.251,83], d[1.104,0.549], g[1.376]
# >20, c[0.272,100], d[0.627,0.325], g[1.036]
# >21, c[0.144,100], d[0.525,0.401], g[1.177]
# >22, c[0.142,100], d[0.566,0.644], g[1.432]
# >23, c[0.305,83], d[0.953,0.429], g[1.296]
# >24, c[0.259,83], d[0.438,0.310], g[1.158]
# >25, c[0.311,83], d[0.655,0.408], g[1.595]
# >26, c[0.282,83], d[0.770,0.368], g[1.536]
# >27, c[0.418,67], d[0.550,0.389], g[1.215]
# >28, c[0.144,100], d[0.586,0.452], g[1.506]
# >29, c[0.397,67], d[0.803,0.455], g[1.395]
# >30, c[0.582,67], d[0.601,0.368], g[1.284]
# >31, c[0.373,83], d[0.442,0.358], g[1.537]
# >32, c[0.331,80], d[0.322,0.360], g[0.929]
# >33, c[0.301,83], d[0.546,0.334], g[1.196]
# >34, c[0.366,83], d[0.780,0.341], g[1.331]
# >35, c[0.194,100], d[0.669,0.305], g[1.136]
# >36, c[0.426,83], d[0.232,0.606], g[1.574]
# >37, c[0.283,83], d[0.535,0.504], g[1.336]
# >38, c[0.185,100], d[0.491,0.493], g[1.105]
# >39, c[0.115,100], d[0.693,0.251], g[1.206]
# >40, c[0.361,83], d[0.387,0.383], g[1.139]
# >41, c[0.303,83], d[0.586,0.445], g[1.232]
# >42, c[0.275,83], d[0.375,0.462], g[1.257]
# >43, c[0.331,83], d[0.468,0.259], g[1.237]
# >44, c[0.248,83], d[0.443,0.434], g[1.414]
# >45, c[0.388,83], d[0.333,0.481], g[1.349]
# >46, c[0.418,83], d[0.548,0.358], g[1.117]
# >47, c[0.300,100], d[0.818,0.440], g[1.226]
# >48, c[0.414,83], d[0.329,0.551], g[1.007]
# >49, c[0.221,83], d[0.356,0.576], g[1.031]
# >50, c[0.281,83], d[0.662,0.576], g[1.219]
# >51, c[0.163,100], d[0.636,0.477], g[1.004]
# >52, c[0.260,83], d[0.601,0.429], g[1.291]
# >53, c[0.205,100], d[0.433,0.369], g[1.113]
# >54, c[0.587,67], d[0.565,0.676], g[1.170]
# >55, c[0.351,83], d[0.435,0.502], g[1.035]
# >56, c[0.615,67], d[0.506,0.619], g[0.700]
# >57, c[0.342,83], d[0.582,0.715], g[1.401]
# >58, c[0.370,83], d[0.683,0.434], g[0.898]
# >59, c[0.245,83], d[0.516,0.574], g[0.743]
# >60, c[0.173,100], d[0.578,0.370], g[1.663]
# >61, c[0.923,50], d[0.517,0.385], g[1.081]
# >62, c[0.238,100], d[0.451,0.521], g[1.287]
# >63, c[0.412,83], d[0.426,0.413], g[1.212]
# >64, c[0.274,100], d[0.342,0.550], g[1.254]
# >65, c[0.371,83], d[0.461,0.589], g[0.926]
# >66, c[0.291,83], d[0.302,0.652], g[0.875]
# >67, c[0.202,100], d[0.324,0.660], g[1.159]
# >68, c[0.565,50], d[0.155,0.481], g[1.276]
# >69, c[0.250,100], d[0.426,0.408], g[1.360]
# >70, c[0.322,83], d[0.420,0.531], g[1.326]
# >71, c[0.470,50], d[0.563,0.343], g[1.372]
# >72, c[0.228,100], d[0.349,0.452], g[1.121]
# >73, c[0.401,67], d[0.425,0.386], g[1.081]
# >74, c[0.238,100], d[0.458,0.449], g[1.112]
# >75, c[0.205,100], d[0.230,0.465], g[1.262]
# >76, c[0.324,83], d[0.457,0.597], g[1.084]
# >77, c[0.072,100], d[0.319,0.409], g[1.285]
# >78, c[0.177,100], d[0.307,0.603], g[0.930]
# >79, c[0.312,83], d[0.461,0.436], g[0.989]
# >80, c[0.270,100], d[0.311,0.486], g[1.172]
# >81, c[0.334,100], d[0.401,0.551], g[0.944]
# >82, c[0.307,83], d[0.781,0.608], g[0.744]
# >83, c[0.253,100], d[0.417,0.527], g[0.953]
# >84, c[0.261,83], d[0.364,0.887], g[1.050]
# >85, c[0.429,83], d[0.468,0.568], g[1.173]
# >86, c[0.257,83], d[0.570,0.786], g[1.059]
# >87, c[0.564,83], d[0.467,0.751], g[0.848]
# 15/15 [==============================] - 0s 23ms/step - loss: 0.6877 - accuracy: 0.6667

# %% [markdown]
# Saving Weights

# %%
# !mkdir -p GAN_weights_NEW/saved_model/c_model/w
# !mkdir -p GAN_weights_NEW/saved_model/d_model/w
# !mkdir -p GAN_weights_NEW/saved_model/d_model/w
# !mkdir -p GAN_weights_NEW/pickle

# !mkdir -p GAN_weights_NEW/saved_model/c_model_best/w

d_model.save_weights('/content/drive/MyDrive/GAN_weights_NEW/saved_model/d_model/w')
c_model.save_weights('/content/drive/MyDrive/GAN_weights_NEW/saved_model/c_model/w')
g_model.save_weights('/content/drive/MyDrive/GAN_weights_NEW/saved_model/d_model/w')

with open('/content/drive/MyDrive/GAN_weights_NEW/pickle/history.pkl', 'wb') as f:
  pickle.dump(history, f)

# %% [markdown]
# # Testing Generative Model

# %%
fake = g_model.predict(generate_latent_points(100, 1))
plt.imshow(fake[0,:,:,0], cmap= "gray")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-f1e1fe94ca93> in <module>()
# ----> 1 fake = g_model.predict(generate_latent_points(100, 1))
#       2 plt.imshow(fake[0,:,:,0], cmap= "gray")
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1725           for step in data_handler.steps():
#    1726             callbacks.on_predict_batch_begin(step)
# -> 1727             tmp_batch_outputs = self.predict_function(iterator)
#    1728             if data_handler.should_sync:
#    1729               context.async_wait()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     887
#     888       with OptionalXlaContext(self._jit_compile):
# --> 889         result = self._call(*args, **kwds)
#     890
#     891       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     931       # This is the first call of __call__, so we have to initialize.
#     932       initializers = []
# --> 933       self._initialize(args, kwds, add_initializers_to=initializers)
#     934     finally:
#     935       # At this point we know that the initialization is complete (or less
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in _initialize(self, args, kwds, add_initializers_to)
#     762     self._concrete_stateful_fn = (
#     763         self._stateful_fn._get_concrete_function_internal_garbage_collected(  # pylint: disable=protected-access
# --> 764             *args, **kwds))
#     765
#     766     def invalid_creator_scope(*unused_args, **unused_kwds):
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in _get_concrete_function_internal_garbage_collected(self, *args, **kwargs)
#    3048       args, kwargs = None, None
#    3049     with self._lock:
# -> 3050       graph_function, _ = self._maybe_define_function(args, kwargs)
#    3051     return graph_function
#    3052
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in _maybe_define_function(self, args, kwargs)
#    3442
#    3443           self._function_cache.missed.add(call_context_key)
# -> 3444           graph_function = self._create_graph_function(args, kwargs)
#    3445           self._function_cache.primary[cache_key] = graph_function
#    3446
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in _create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    3287             arg_names=arg_names,
#    3288             override_flat_arg_shapes=override_flat_arg_shapes,
# -> 3289             capture_by_value=self._capture_by_value),
#    3290         self._function_attributes,
#    3291         function_spec=self.function_spec,
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes)
#     997         _, original_func = tf_decorator.unwrap(python_func)
#     998
# --> 999       func_outputs = python_func(*func_args, **func_kwargs)
#    1000
#    1001       # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in wrapped_fn(*args, **kwds)
#     670         # the function a weak reference to itself to avoid a reference cycle.
#     671         with OptionalXlaContext(compile_with_xla):
# --> 672           out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     673         return out
#     674
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/func_graph.py in wrapper(*args, **kwargs)
#     984           except Exception as e:  # pylint:disable=broad-except
#     985             if hasattr(e, "ag_error_metadata"):
# --> 986               raise e.ag_error_metadata.to_exception(e)
#     987             else:
#     988               raise
#
# ValueError: in user code:
#
#     /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1569 predict_function  *
#         return step_function(self, iterator)
#     /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1559 step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     /usr/local/lib/python3.7/dist-packages/tensorflow/python/distribute/distribute_lib.py:1285 run
#         return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#     /usr/local/lib/python3.7/dist-packages/tensorflow/python/distribute/distribute_lib.py:2833 call_for_each_replica
#         return self._call_for_each_replica(fn, args, kwargs)
#     /usr/local/lib/python3.7/dist-packages/tensorflow/python/distribute/distribute_lib.py:3608 _call_for_each_replica
#         return fn(*args, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1552 run_step  **
#         outputs = model.predict_step(data)
#     /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1525 predict_step
#         return self(x, training=False)
#     /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/base_layer.py:1013 __call__
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/input_spec.py:270 assert_input_compatibility
#         ', found shape=' + display_shape(x.shape))
#
#     ValueError: Input 0 is incompatible with layer model_2: expected shape=(None, 150), found shape=(None, 100)

# %%
# test_AMDgen = tf.keras.preprocessing.image.ImageDataGenerator(
#     rescale            = 1./255,
# )

# test_AMD = test_AMDgen.flow_from_directory(
#     'NewEye/test/AMDD',
#     target_size = (416,288),
#     batch_size  = batch_size * 4,
#     color_mode  = "grayscale",
#     class_mode  = None,
# )

# test_CSRgen = tf.keras.preprocessing.image.ImageDataGenerator(
#     rescale            = 1./255,
# )

# test_CSR = test_CSRgen.flow_from_directory(
#     'NewEye/test/CSRD',
#     target_size = (416,288),
#     batch_size  = batch_size * 4,
#     color_mode  = "grayscale",
#     class_mode  = None,
# )

test_DRgen = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale            = 1./255,
)

test_DR = test_DRgen.flow_from_directory(
    'NewEye/test/D/DRD',
    target_size = (416,288),
    batch_size  = batch_size * 4,
    color_mode  = "grayscale",
    class_mode  = None,
)

test_NORMALgen = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale            = 1./255,
)

test_NORMAL = test_NORMALgen.flow_from_directory(
    'NewEye/test/D/NORMALD',
    target_size = (416,288),
    batch_size  = batch_size * 4,
    color_mode  = "grayscale",
    class_mode  = None,
)

test_MHgen = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale            = 1./255,
)

test_MH = test_MHgen.flow_from_directory(
    'NewEye/test/D/MHD',
    target_size = (416,288),
    batch_size  = batch_size * 4,
    color_mode  = "grayscale",
    class_mode  = None,
)
# Out:
# Found 10 images belonging to 1 classes.
# Found 10 images belonging to 1 classes.
# Found 10 images belonging to 1 classes.

# %%
#predictAMD = c_model.predict(test_AMD)
predictNORMAL = c_model.predict(test_NORMAL)
predictDR = c_model.predict(test_DR)
##predictCSR = c_model.predict(test_CSR)
predictMH = c_model.predict(test_MH)

#predictAMD = [np.argmax(i) for i in predictAMD]
predictNORMAL = [np.argmax(i) for i in predictNORMAL]
predictDR = [np.argmax(i) for i in predictDR]
#predictCSR = [np.argmax(i) for i in predictCSR]
predictMH = [np.argmax(i) for i in predictMH]

# %%
true_AMD    = np.array([0] * 10)
true_NORMAL = np.array([4] * 10)
true_CSR    = np.array([1] * 10)
true_DR     = np.array([2] * 10)
true_MH     = np.array([3] * 10)

# %%
#AMDmetrics = tf.keras.metrics.Accuracy()
#AMDmetrics.update_state(true_AMD, predictAMD)
NORMALmetrics = tf.keras.metrics.Accuracy()
NORMALmetrics.update_state(true_NORMAL, predictNORMAL)
#CSRmetrics = tf.keras.metrics.Accuracy()
#CSRmetrics.update_state(true_CSR, predictCSR)
DRmetrics = tf.keras.metrics.Accuracy()
DRmetrics.update_state(true_DR, predictDR)
MHmetrics = tf.keras.metrics.Accuracy()
MHmetrics.update_state(true_MH, predictMH)
#print(f"AMD: {AMDmetrics.result().numpy()}, CSR: {CSRmetrics.result().numpy()}, NORMAL: {NORMALmetrics.result().numpy()}, DR: {DRmetrics.result().numpy()}, MH: {MHmetrics.result().numpy()}")
print(f"MH: {MHmetrics.result().numpy()}")
print(f"NORMAL: {NORMALmetrics.result().numpy()}")
print(f"DR: {DRmetrics.result().numpy()}")
# Out:
# MH: 0.0
# NORMAL: 0.0
# DR: 0.0

# %%
c_model.evaluate(test_data)
# Out:
# 15/15 [==============================] - 1s 19ms/step - loss: 0.4757 - accuracy: 0.9333
# [0.4756849706172943, 0.9333333373069763]
